# %% [markdown]
# ### 1. Installing dependencies

# %%
# !pip install gymnasium gym-anytrading pandas matplotlib stable-baselines3[extra] finta
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: gym-anytrading in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: finta in /usr/local/lib/python3.10/dist-packages (1.3)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.4.0+cu121)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.8.0)
# Requirement already satisfied: shimmy~=1.3.0 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: autorom~=0.6.1 in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.32.3)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (71.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.4.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)

# %% [markdown]
# ### 2. importing packages

# %%
import gymnasium as gym
import gym_anytrading
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os


from gym_anytrading.envs import TradingEnv, ForexEnv, StocksEnv, Actions, Positions

from stable_baselines3 import DQN
from stable_baselines3 import A2C
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback



from gym_anytrading.envs import StocksEnv
from finta import TA

# %% [markdown]
# ### Constant

# %%
WINDOW_SIZE = 14
DATASET_PATH = '/content/Processed_predicted_TSLA (1).csv'

# %% [markdown]
# ### 3. Read the dataset and preprocess it

# %%
df = pd.read_csv(DATASET_PATH)

# %%
df['Date'] = pd.to_datetime(df.Date)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Unnamed: 0       Date   Open   High    Low  Close  Adj Close    Volume  \
# 0           0 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1           1 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2           2 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3           3 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4           4 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
#
#    Sentiment  Predicted_Close
# 0          1              NaN
# 1          0              NaN
# 2          0              NaN
# 3          1              NaN
# 4         -1              NaN

# %%
df.isna().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Unnamed: 0           0
# Date                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Adj Close            0
# Volume               0
# Sentiment            0
# Predicted_Close    100
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Adj Close          0
# Volume             0
# Sentiment          0
# Predicted_Close    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2856 entries, 100 to 2955
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2856 non-null   int64
#  1   Date             2856 non-null   datetime64[ns]
#  2   Open             2856 non-null   float64
#  3   High             2856 non-null   float64
#  4   Low              2856 non-null   float64
#  5   Close            2856 non-null   float64
#  6   Adj Close        2856 non-null   float64
#  7   Volume           2856 non-null   int64
#  8   Sentiment        2856 non-null   int64
#  9   Predicted_Close  2856 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 245.4 KB

# %%
df.set_index('Date', inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#             Unnamed: 0   Open   High    Low  Close  Adj Close   Volume  \
# Date
# 2010-11-18         100  6.134  6.148  5.784  5.978      5.978  4780500
# 2010-11-19         101  6.032  6.274  5.940  6.198      6.198  5752500
# 2010-11-22         102  6.314  6.690  6.300  6.680      6.680  7648500
# 2010-11-23         103  6.658  7.136  6.438  6.914      6.914  7889000
# 2010-11-24         104  7.054  7.194  6.866  7.094      7.094  7125000
#
#             Sentiment  Predicted_Close
# Date
# 2010-11-18          0         9.990785
# 2010-11-19          0         9.645310
# 2010-11-22          0         9.681129
# 2010-11-23          0        10.123896
# 2010-11-24          0        10.545571

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2856 entries, 2010-11-18 to 2022-03-24
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2856 non-null   int64
#  1   Open             2856 non-null   float64
#  2   High             2856 non-null   float64
#  3   Low              2856 non-null   float64
#  4   Close            2856 non-null   float64
#  5   Adj Close        2856 non-null   float64
#  6   Volume           2856 non-null   int64
#  7   Sentiment        2856 non-null   int64
#  8   Predicted_Close  2856 non-null   float64
# dtypes: float64(6), int64(3)
# memory usage: 223.1 KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['SMA'] = TA.SMA(df, WINDOW_SIZE)
df['RSI'] = TA.RSI(df, WINDOW_SIZE)
df['MOM'] = TA.MOM(df, WINDOW_SIZE)
df['OBV'] = TA.OBV(df,'close')
df['EMA'] = TA.EMA(df, WINDOW_SIZE)
df['Stochastic oscillator'] = TA.AO(df,WINDOW_SIZE)
df['AD'] = TA.ADL(df)
df['ROC'] = TA.ROC(df,WINDOW_SIZE)
df.fillna(0, inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.drop(columns='Unnamed: 0', inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(50)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              Open   High    Low  Close  Adj Close    Volume  Sentiment  \
# Date
# 2010-11-18  6.134  6.148  5.784  5.978      5.978   4780500          0
# 2010-11-19  6.032  6.274  5.940  6.198      6.198   5752500          0
# 2010-11-22  6.314  6.690  6.300  6.680      6.680   7648500          0
# 2010-11-23  6.658  7.136  6.438  6.914      6.914   7889000          0
# 2010-11-24  7.054  7.194  6.866  7.094      7.094   7125000          0
# 2010-11-26  7.120  7.200  6.950  7.064      7.064   1753000          0
# 2010-11-29  7.082  7.190  6.666  6.866      6.866   5728000          0
# 2010-11-30  6.748  7.066  6.682  7.066      7.066  11113000          0
# 2010-12-01  7.174  7.284  6.690  6.870      6.870   6496000          0
# 2010-12-02  6.802  6.860  6.240  6.470      6.470  10035000          0
# 2010-12-03  6.402  6.450  6.174  6.298      6.298   5800500          0
# 2010-12-06  6.270  6.290  5.912  6.062      6.062   6372000          0
# 2010-12-07  6.098  6.480  6.010  6.312      6.312   6556500          0
# 2010-12-08  6.496  6.498  6.304  6.474      6.474   3300000          0
# 2010-12-09  6.502  6.544  6.330  6.410      6.410   2030000          0
# 2010-12-10  6.410  6.584  6.226  6.304      6.304   2147000          0
# 2010-12-13  6.328  6.354  6.080  6.110      6.110   2052000          0
# 2010-12-14  6.058  6.078  5.552  5.706      5.706   8828500          0
# 2010-12-15  5.734  5.994  5.706  5.920      5.920   3714500          0
# 2010-12-16  6.000  6.182  5.930  6.162      6.162   3950500          0
# 2010-12-17  6.268  6.308  6.142  6.272      6.272   4065000          0
# 2010-12-20  6.328  6.438  6.252  6.340      6.340   2617000          0
# 2010-12-21  6.360  6.538  6.342  6.452      6.452   3888500          0
# 2010-12-22  6.450  6.572  6.340  6.526      6.526   4166500          0
# 2010-12-23  6.252  6.496  5.984  6.018      6.018   7763000          0
# 2010-12-27  5.604  5.716  5.012  5.110      5.110  46509500         -1
# 2010-12-28  5.170  5.350  5.000  5.282      5.282  20281500          1
# 2010-12-29  5.406  5.602  5.300  5.546      5.546  16596000          0
# 2010-12-30  5.540  5.580  5.276  5.300      5.300  10205500          0
# 2010-12-31  5.314  5.450  5.300  5.326      5.326   7089500          0
# 2011-01-03  5.368  5.400  5.180  5.324      5.324   6415000          0
# 2011-01-04  5.332  5.390  5.204  5.334      5.334   5937000          0
# 2011-01-05  5.296  5.380  5.238  5.366      5.366   7233500          0
# 2011-01-06  5.366  5.600  5.362  5.576      5.576  10306000          0
# 2011-01-07  5.600  5.716  5.580  5.648      5.648  11239500          0
# 2011-01-10  5.634  5.736  5.610  5.690      5.690   6713500          0
# 2011-01-11  5.718  5.742  5.384  5.392      5.392   8551000          0
# 2011-01-12  5.402  5.480  5.304  5.392      5.392   4822000          0
# 2011-01-13  5.392  5.394  5.232  5.244      5.244   3618000          0
# 2011-01-14  5.230  5.316  5.122  5.150      5.150   5960000          0
# 2011-01-18  5.096  5.128  4.950  5.128      5.128   8108500          0
# 2011-01-19  5.054  5.094  4.750  4.806      4.806  11857500          0
# 2011-01-20  4.806  4.890  4.474  4.524      4.524  11399500          0
# 2011-01-21  4.624  4.718  4.542  4.608      4.608   6085000          0
# 2011-01-24  4.706  4.962  4.646  4.898      4.898   8225500          0
# 2011-01-25  4.930  4.978  4.804  4.936      4.936   6357500          0
# 2011-01-26  4.942  4.976  4.820  4.950      4.950   5399500          0
# 2011-01-27  4.948  5.016  4.906  4.984      4.984   4478500          0
# 2011-01-28  4.976  4.976  4.750  4.802      4.802   5242000          0
# 2011-01-31  4.810  4.824  4.700  4.820      4.820   4151500          0
#
#             Predicted_Close       SMA         RSI    MOM         OBV  \
# Date
# 2010-11-18         9.990785  0.000000    0.000000  0.000         0.0
# 2010-11-19         9.645310  0.000000  100.000000  0.000   5752500.0
# 2010-11-22         9.681129  0.000000  100.000000  0.000  13401000.0
# 2010-11-23        10.123896  0.000000  100.000000  0.000  21290000.0
# 2010-11-24        10.545571  0.000000  100.000000  0.000  28415000.0
# 2010-11-26        10.813133  0.000000   96.836734  0.000  26662000.0
# 2010-11-29        10.576933  0.000000   79.061031  0.000  20934000.0
# 2010-11-30        10.370217  0.000000   82.546215  0.000  32047000.0
# 2010-12-01        10.662851  0.000000   70.212458  0.000  25551000.0
# 2010-12-02        10.775242  0.000000   52.855397  0.000  15516000.0
# 2010-12-03        10.723429  0.000000   47.426224  0.000   9715500.0
# 2010-12-06        10.365671  0.000000   41.176485  0.000   3343500.0
# 2010-12-07        10.069236  0.000000   48.863951  0.000   9900000.0
# 2010-12-08        10.015172  6.596143   53.137758  0.000  13200000.0
# 2010-12-09         9.930625  6.627000   51.313164  0.432  11170000.0
# 2010-12-10         9.762336  6.634571   48.351836  0.106   9023000.0
# 2010-12-13         9.620625  6.593857   43.413679 -0.570   6971000.0
# 2010-12-14         9.528059  6.507571   35.323169 -1.208  -1857500.0
# 2010-12-15         9.721762  6.423714   41.538139 -1.174   1857000.0
# 2010-12-16         9.705574  6.359286   47.662863 -0.902   5807500.0
# 2010-12-17         9.681859  6.316857   50.215953 -0.594   9872500.0
# 2010-12-20         9.752096  6.265000   51.781866 -0.726  12489500.0
# 2010-12-21         9.748876  6.235143   54.329887 -0.418  16378000.0
# 2010-12-22         9.805564  6.239143   55.984869  0.056  20544500.0
# 2010-12-23         9.928851  6.219143   44.155480 -0.280  12781500.0
# 2010-12-27        10.084022  6.151143   31.388900 -0.952 -33728000.0
# 2010-12-28        17.203721  6.077571   35.210306 -1.030 -13446500.0
# 2010-12-29        16.230860  6.011286   40.672245 -0.928   3149500.0
# 2010-12-30        11.631501  5.932000   37.499856 -1.110  -7056000.0
# 2010-12-31        10.701219  5.862143   38.049845 -0.978     33500.0
# 2011-01-03         9.904197  5.806000   38.022128 -0.786  -6381500.0
# 2011-01-04         9.443632  5.779429   38.264280 -0.372   -444500.0
# 2011-01-05         9.236618  5.739857   39.084470 -0.554   6789000.0
# 2011-01-06         9.302696  5.698000   44.313070 -0.586  17095000.0
# 2011-01-07         9.584985  5.653429   46.023709 -0.624  28334500.0
# 2011-01-10         9.831977  5.607000   47.045609 -0.650  35048000.0
# 2011-01-11         9.846719  5.531286   41.099969 -1.060  26497000.0
# 2011-01-12         9.787349  5.450286   41.099969 -1.134         0.0
# 2011-01-13         9.443185  5.395000   38.311155 -0.774  22879000.0
# 2011-01-14         9.100198  5.397857   36.611928  0.040  16919000.0
# 2011-01-18         9.030855  5.386857   36.207165 -0.154   8810500.0
# 2011-01-19         9.212828  5.334000   30.834050 -0.740  -3047000.0
# 2011-01-20         9.281246  5.278571   27.048319 -0.776 -14446500.0
# 2011-01-21         9.231460  5.227286   29.812668 -0.718  -8361500.0
# 2011-01-24         9.034999  5.196857   38.479856 -0.426   -136000.0
# 2011-01-25         9.051977  5.168429   39.533526 -0.398   6221500.0
# 2011-01-26         9.040321  5.138714   39.941648 -0.416  11621000.0
# 2011-01-27         8.940197  5.096429   40.983448 -0.592  16099500.0
# 2011-01-28         8.832278  5.036000   37.257772 -0.846  10857500.0
# 2011-01-31         8.773355  4.973857   37.859441 -0.870  15009000.0
#
#                  EMA  Stochastic oscillator            AD        ROC
# Date
# 2010-11-18  5.978000               0.000000  3.151978e+05   0.000000
# 2010-11-19  6.095857               0.000000  3.449794e+06   0.000000
# 2010-11-22  6.319002               0.000000  1.070606e+07   0.000000
# 2010-11-23  6.501028               0.000000  1.357685e+07   0.000000
# 2010-11-24  6.655734               0.000000  1.635733e+07   0.000000
# 2010-11-26  6.750199               0.000000  1.620307e+07   0.000000
# 2010-11-29  6.774601               0.000000  1.484759e+07   0.000000
# 2010-11-30  6.831594               0.000000  2.596059e+07   0.000000
# 2010-12-01  6.838666               0.000000  2.340156e+07   0.000000
# 2010-12-02  6.774067               0.000000  2.081188e+07   0.000000
# 2010-12-03  6.694003               0.000000  2.022342e+07   0.000000
# 2010-12-06  6.591292               0.000000  1.890857e+07   0.000000
# 2010-12-07  6.547190               0.000000  2.077787e+07   0.000000
# 2010-12-08  6.535910              -0.239486  2.326137e+07   0.000000
# 2010-12-09  6.516900              -0.295729  2.274913e+07   7.226497
# 2010-12-10  6.485313              -0.298414  2.153769e+07   1.710229
# 2010-12-13  6.430455              -0.255357  1.993504e+07  -8.532934
# 2010-12-14  6.325906              -0.271929  1.627608e+07 -17.471796
# 2010-12-15  6.267964              -0.297843  1.808174e+07 -16.549197
# 2010-12-16  6.252979              -0.301257  2.140517e+07 -12.768969
# 2010-12-17  6.255647              -0.287043  2.370704e+07  -8.651325
# 2010-12-20  6.267399              -0.223657  2.356634e+07 -10.274554
# 2010-12-21  6.292963              -0.059586  2.404248e+07  -6.084425
# 2010-12-22  6.325070               0.068329  2.655675e+07   0.865533
# 2010-12-23  6.282950               0.110271  1.982477e+07  -4.445856
# 2010-12-27  6.122675              -0.009286 -1.373606e+07 -15.704388
# 2010-12-28  6.008182              -0.166857 -1.335370e+06 -16.318124
# 2010-12-29  5.945416              -0.296800  9.105823e+06 -14.334260
# 2010-12-30  5.857982              -0.430329  5.117173e+05 -17.316693
# 2010-12-31  5.786069              -0.529757 -4.120089e+06 -15.513959
# 2011-01-03  5.723721              -0.478343 -2.137271e+06 -12.864157
# 2011-01-04  5.671220              -0.416943  2.247610e+05  -6.519453
# 2011-01-05  5.630158              -0.406700  6.031937e+06  -9.358108
# 2011-01-06  5.622881              -0.355029  1.425942e+07  -9.509899
# 2011-01-07  5.626253              -0.259214  1.425942e+07  -9.948980
# 2011-01-10  5.634802              -0.134614  1.607100e+07 -10.252366
# 2011-01-11  5.602265              -0.018771  7.902163e+06 -16.429014
# 2011-01-12  5.574107               0.073829  7.902163e+06 -17.376647
# 2011-01-13  5.529926               0.106443  4.820163e+06 -12.861416
# 2011-01-14  5.479104               0.031000  5.805754e+05   0.782779
# 2011-01-18  5.432157              -0.086086  8.689075e+06  -2.915562
# 2011-01-19  5.348464              -0.176500  6.921568e+05 -13.342950
# 2011-01-20  5.238301              -0.265214 -7.967079e+06 -14.641509
# 2011-01-21  5.154106              -0.348600 -9.488329e+06 -13.481036
# 2011-01-24  5.119904              -0.396886 -4.594677e+06  -8.001503
# 2011-01-25  5.095349              -0.397486 -1.306315e+06  -7.461567
# 2011-01-26  5.075946              -0.372929  2.293352e+06  -7.752516
# 2011-01-27  5.063674              -0.279986  4.166179e+06 -10.616930
# 2011-01-28  5.028753              -0.177314  1.336427e+06 -14.978754
# 2011-01-31  5.000897              -0.120643  5.220088e+06 -15.289982

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    diff = np.insert(np.diff(prices), 0, 0)
    signal_features = env.df.loc[:, ['Close','Predicted_Close','Sentiment','SMA', 'RSI', 'MOM', 'OBV', 'EMA', 'Stochastic oscillator', 'AD', 'ROC']].to_numpy()[start:end]
    # Reshape diff to (282, 1)
    diff_reshaped = diff.reshape(len(diff), 1)

    # Concatenate along the second axis (columns)
    signal_features = np.concatenate((signal_features, diff_reshaped), axis=1)


    return prices, signal_features
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-WINDOW_SIZE:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals

    def reset(self, seed=None, options=None):
      super().reset(seed=seed, options=options)
      self.action_space.seed(int((self.np_random.uniform(0, seed if seed is not None else 1))))

      self._truncated = False
      self._current_tick = self._start_tick
      self._last_trade_tick = self._current_tick - 1
      self._position = Positions.Short
      self._position_history = (self.window_size * [None]) + [self._position]
      self._total_reward = 0.
      self._total_profit = 1000.  # unit
      self._first_rendering = True
      self.history = {}

      observation = self._get_observation()
      info = self._get_info()

      if self.render_mode == 'human':
          self._render_frame()

      return observation, info

# %%
train_df = df.loc[df.index < '2019-01-01']
test_df = df.loc[df.index >= '2019-01-01']

print('train_df: ',len(train_df))
print('test_df: ',len(test_df))
# Out:
# train_df:  2042
# test_df:  814

# %%
train_df.shape
# Out:
# (2042, 16)

# %%
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# %%
env = MyCustomEnv(df=train_df, frame_bound=(WINDOW_SIZE, len(train_df)), window_size=WINDOW_SIZE)

env = Monitor(env, log_dir)

# %%
env.signal_features[:1,:]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.signal_features to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.signal_features` for environment variables or `env.get_wrapper_attr('signal_features')` that will search the reminding wrappers.
#   logger.warn(
# array([[5.97800000e+00, 9.99078546e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.97800000e+00,
#         0.00000000e+00, 3.15197802e+05, 0.00000000e+00, 0.00000000e+00]])

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# Discrete: describes a discrete space where {0, 1, …, n-1} are the possible values our observation or action can take. Values can be shifted to {a, a+1, …, a+n-1} using an optional argument.

# %%
env.action_space.sample()
# Out:
# 0

# %% [markdown]
# Sell = 0
#
# Buy = 1

# %%
env.observation_space
# Out:
# Box(-10000000000.0, 10000000000.0, (14, 12), float32)

# %% [markdown]
# Box: describes an n-dimensional continuous space. It’s a bounded space where we can define the upper and lower limits which describe the valid values our observations can take.

# %%
env.observation_space.sample()
# Out:
# array([[-4.0004344e+09, -6.0870154e+09, -1.9946335e+09, -4.1262328e+09,
#          6.9241784e+09,  8.3179238e+09,  3.7913810e+09,  5.6075633e+09,
#          3.7339843e+09,  4.4287171e+09,  7.9378237e+09,  8.6989933e+08],
#        [ 2.5561229e+09, -3.9327777e+09, -5.5972634e+09, -2.5745021e+09,
#         -4.8737311e+09, -6.8781453e+08, -6.7413294e+09,  4.2526446e+09,
#         -7.5319148e+09, -8.7605064e+09,  6.2346353e+09,  1.6214022e+09],
#        [ 6.9132902e+09,  3.5474870e+09, -5.2270848e+09, -2.3087173e+08,
#         -6.0021202e+09, -9.4162995e+09,  1.3341811e+09,  5.1548805e+09,
#         -3.2978419e+09, -7.4900137e+09,  4.3305923e+09, -9.2402867e+08],
#        [-4.1679616e+09,  7.2927652e+09,  2.3796273e+09,  9.6387471e+09,
#         -9.5649403e+09, -2.9622013e+09,  7.3529953e+09, -8.1252383e+09,
#          2.4853176e+09,  7.2821345e+09,  8.3077709e+09,  2.7130954e+09],
#        [-2.1261805e+09, -4.9906253e+09, -7.2797153e+09, -2.7474685e+09,
#          1.8890113e+09, -9.3843773e+09,  8.6452000e+08,  9.2612055e+09,
#         -4.7227469e+09, -8.7521597e+09,  2.7317161e+09,  1.8574094e+08],
#        [-1.1514680e+09,  9.2248658e+09, -6.9465180e+09, -6.5665792e+09,
#         -1.5626388e+09, -4.3045018e+09, -1.5551694e+09, -6.1523579e+09,
#         -9.3972756e+09,  7.6338662e+09, -2.6035821e+08,  7.5721795e+09],
#        [ 3.4889285e+09,  6.4236959e+09, -8.2756470e+09,  6.5565097e+09,
#         -3.0216960e+09,  3.8787809e+09,  5.9175204e+09, -3.8882811e+09,
#          1.9220216e+09,  3.6616886e+09,  1.1033326e+08, -7.2903598e+09],
#        [-6.8338852e+09,  1.7371762e+09, -4.2819172e+09,  8.6185779e+09,
#          6.0112451e+09, -9.7768704e+09,  6.7128724e+09,  5.7810662e+09,
#          8.3284746e+09,  5.7009478e+08, -6.0978202e+08, -8.3734144e+09],
#        [-3.5079741e+09,  2.3549053e+09, -9.0268375e+09, -9.8619638e+09,
#         -8.4894705e+09, -7.8441313e+09, -9.1596728e+09,  4.3179818e+08,
#          8.3765883e+09,  4.1718221e+09, -7.7290184e+09, -4.0146081e+09],
#        [-8.7652516e+09, -3.3859671e+09, -3.4020014e+09, -2.9393382e+09,
#         -9.8070333e+09, -9.4975693e+09, -3.1845194e+09,  8.6696049e+09,
#          2.1245783e+09, -2.6307476e+09, -2.7491264e+09, -4.4327071e+09],
#        [-9.9688110e+09,  5.1229251e+09,  2.7248218e+09,  9.8028790e+09,
#          1.5561444e+09, -6.5346017e+09,  4.1653018e+09,  3.8925740e+09,
#          4.9524818e+09,  3.3387889e+09,  9.8181335e+09,  9.9076198e+08],
#        [ 3.7393779e+09,  5.8576942e+09,  5.6554696e+09,  1.3675944e+09,
#         -7.9494984e+09, -8.7713034e+09,  8.9577400e+09,  2.6193065e+09,
#          3.4956086e+09, -4.8177235e+06, -1.7844630e+09,  7.1043031e+09],
#        [ 1.8979438e+09,  7.8683843e+09,  5.0402063e+09,  6.0632003e+09,
#          6.9257370e+09,  9.5558154e+09, -9.1463803e+09,  2.9662275e+09,
#          7.2727429e+09,  6.8442993e+09,  5.3082854e+09, -1.3722388e+09],
#        [ 1.6640817e+09,  8.2558065e+09,  3.6481377e+09,  3.6971471e+09,
#          7.9603117e+08,  3.0799974e+09, -2.7421354e+08,  1.8631329e+09,
#          8.2697171e+08,  3.6549622e+09, -2.4536238e+09,  3.2908009e+09]],
#       dtype=float32)

# %% [markdown]
# ### 4. Create the environment and do some random action on it

# %%
observation = env.reset(seed=2024)
while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    # env.render()
    if done:
        print("info:", info)
        break

plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info: {'total_reward': 35.21602300000002, 'total_profit': 1.8084458704564477, 'position': <Positions.Short: 0>, 'episode': {'r': 35.216023, 'l': 2027, 't': 0.132695}}

# %% [markdown]
# ### 5 creating and training the model

# %%
model = A2C("MlpPolicy", env, verbose=1)

# Create the callback: check every 2142 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=2142, log_dir=log_dir)

# Train the model
model.learn(total_timesteps=428400,callback=callback)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    n_updates          | 56999    |
# |    policy_loss        | -0.0023  |
# |    value_loss         | 0.00312  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.9     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57100    |
# |    time_elapsed       | 671      |
# |    total_timesteps    | 285500   |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | -2.6     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57099    |
# |    policy_loss        | 0.000514 |
# |    value_loss         | 0.000261 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.7     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57200    |
# |    time_elapsed       | 672      |
# |    total_timesteps    | 286000   |
# | train/                |          |
# |    entropy_loss       | -0.232   |
# |    explained_variance | -0.352   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57199    |
# |    policy_loss        | -0.00661 |
# |    value_loss         | 0.00359  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.7     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57300    |
# |    time_elapsed       | 673      |
# |    total_timesteps    | 286500   |
# | train/                |          |
# |    entropy_loss       | -0.0828  |
# |    explained_variance | -2.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57299    |
# |    policy_loss        | -0.00307 |
# |    value_loss         | 0.033    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.7     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57400    |
# |    time_elapsed       | 674      |
# |    total_timesteps    | 287000   |
# | train/                |          |
# |    entropy_loss       | -0.0508  |
# |    explained_variance | 0.215    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57399    |
# |    policy_loss        | 0.0504   |
# |    value_loss         | 12.8     |
# ------------------------------------
# Num timesteps: 287028
# Best mean reward: 67.87 - Last mean reward per episode: 45.78
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.7     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57500    |
# |    time_elapsed       | 676      |
# |    total_timesteps    | 287500   |
# | train/                |          |
# |    entropy_loss       | -0.246   |
# |    explained_variance | 0.000304 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57499    |
# |    policy_loss        | -0.139   |
# |    value_loss         | 10.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.6     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57600    |
# |    time_elapsed       | 677      |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.169   |
# |    explained_variance | -24.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57599    |
# |    policy_loss        | 0.0288   |
# |    value_loss         | 0.0312   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.6     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57700    |
# |    time_elapsed       | 678      |
# |    total_timesteps    | 288500   |
# | train/                |          |
# |    entropy_loss       | -0.223   |
# |    explained_variance | -0.166   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57699    |
# |    policy_loss        | 0.0173   |
# |    value_loss         | 0.141    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.6     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57800    |
# |    time_elapsed       | 679      |
# |    total_timesteps    | 289000   |
# | train/                |          |
# |    entropy_loss       | -0.0148  |
# |    explained_variance | 0.0168   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57799    |
# |    policy_loss        | 0.303    |
# |    value_loss         | 0.0368   |
# ------------------------------------
# Num timesteps: 289170
# Best mean reward: 67.87 - Last mean reward per episode: 47.84
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.6     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 57900    |
# |    time_elapsed       | 680      |
# |    total_timesteps    | 289500   |
# | train/                |          |
# |    entropy_loss       | -0.283   |
# |    explained_variance | -0.0319  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57899    |
# |    policy_loss        | 0.0843   |
# |    value_loss         | 1.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.4     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58000    |
# |    time_elapsed       | 681      |
# |    total_timesteps    | 290000   |
# | train/                |          |
# |    entropy_loss       | -0.132   |
# |    explained_variance | -16.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57999    |
# |    policy_loss        | 0.00259  |
# |    value_loss         | 0.00961  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.4     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58100    |
# |    time_elapsed       | 682      |
# |    total_timesteps    | 290500   |
# | train/                |          |
# |    entropy_loss       | -0.223   |
# |    explained_variance | 0.191    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58099    |
# |    policy_loss        | 0.0424   |
# |    value_loss         | 0.744    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.4     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58200    |
# |    time_elapsed       | 683      |
# |    total_timesteps    | 291000   |
# | train/                |          |
# |    entropy_loss       | -0.179   |
# |    explained_variance | -3.74    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58199    |
# |    policy_loss        | -0.00233 |
# |    value_loss         | 0.00157  |
# ------------------------------------
# Num timesteps: 291312
# Best mean reward: 67.87 - Last mean reward per episode: 49.04
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.4     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58300    |
# |    time_elapsed       | 684      |
# |    total_timesteps    | 291500   |
# | train/                |          |
# |    entropy_loss       | -0.197   |
# |    explained_variance | -7.94    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58299    |
# |    policy_loss        | -0.00354 |
# |    value_loss         | 0.0055   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.7     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58400    |
# |    time_elapsed       | 685      |
# |    total_timesteps    | 292000   |
# | train/                |          |
# |    entropy_loss       | -0.0824  |
# |    explained_variance | 0.101    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58399    |
# |    policy_loss        | -0.00242 |
# |    value_loss         | 0.0115   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 51.7      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 58500     |
# |    time_elapsed       | 686       |
# |    total_timesteps    | 292500    |
# | train/                |           |
# |    entropy_loss       | -0.0136   |
# |    explained_variance | -7.79     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58499     |
# |    policy_loss        | -0.000136 |
# |    value_loss         | 0.00372   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.7     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58600    |
# |    time_elapsed       | 687      |
# |    total_timesteps    | 293000   |
# | train/                |          |
# |    entropy_loss       | -0.0299  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58599    |
# |    policy_loss        | 5.94     |
# |    value_loss         | 23.7     |
# ------------------------------------
# Num timesteps: 293454
# Best mean reward: 67.87 - Last mean reward per episode: 50.19
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 51.7     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58700    |
# |    time_elapsed       | 689      |
# |    total_timesteps    | 293500   |
# | train/                |          |
# |    entropy_loss       | -0.0636  |
# |    explained_variance | -0.0153  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58699    |
# |    policy_loss        | 0.00323  |
# |    value_loss         | 0.067    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.6      |
# | time/                 |           |
# |    fps                | 425       |
# |    iterations         | 58800     |
# |    time_elapsed       | 690       |
# |    total_timesteps    | 294000    |
# | train/                |           |
# |    entropy_loss       | -0.0082   |
# |    explained_variance | -147      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58799     |
# |    policy_loss        | -0.000132 |
# |    value_loss         | 0.00885   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.6     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 58900    |
# |    time_elapsed       | 691      |
# |    total_timesteps    | 294500   |
# | train/                |          |
# |    entropy_loss       | -0.302   |
# |    explained_variance | 0.0178   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58899    |
# |    policy_loss        | 1.19     |
# |    value_loss         | 1.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.6     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 59000    |
# |    time_elapsed       | 692      |
# |    total_timesteps    | 295000   |
# | train/                |          |
# |    entropy_loss       | -0.19    |
# |    explained_variance | -1.77    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58999    |
# |    policy_loss        | -0.00156 |
# |    value_loss         | 0.00125  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.6      |
# | time/                 |           |
# |    fps                | 425       |
# |    iterations         | 59100     |
# |    time_elapsed       | 693       |
# |    total_timesteps    | 295500    |
# | train/                |           |
# |    entropy_loss       | -0.0439   |
# |    explained_variance | -0.00879  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59099     |
# |    policy_loss        | -0.000195 |
# |    value_loss         | 0.00555   |
# -------------------------------------
# Num timesteps: 295596
# Best mean reward: 67.87 - Last mean reward per episode: 51.58
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.8     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 59200    |
# |    time_elapsed       | 694      |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -0.113   |
# |    explained_variance | -113     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59199    |
# |    policy_loss        | -0.0132  |
# |    value_loss         | 0.0404   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.8      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 59300     |
# |    time_elapsed       | 695       |
# |    total_timesteps    | 296500    |
# | train/                |           |
# |    entropy_loss       | -0.000243 |
# |    explained_variance | -4.1      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59299     |
# |    policy_loss        | 2.68e-06  |
# |    value_loss         | 0.0102    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.8      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 59400     |
# |    time_elapsed       | 696       |
# |    total_timesteps    | 297000    |
# | train/                |           |
# |    entropy_loss       | -0.329    |
# |    explained_variance | -10.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59399     |
# |    policy_loss        | -0.000836 |
# |    value_loss         | 0.00154   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.8     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 59500    |
# |    time_elapsed       | 697      |
# |    total_timesteps    | 297500   |
# | train/                |          |
# |    entropy_loss       | -0.0267  |
# |    explained_variance | -0.0351  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59499    |
# |    policy_loss        | 0.0016   |
# |    value_loss         | 0.311    |
# ------------------------------------
# Num timesteps: 297738
# Best mean reward: 67.87 - Last mean reward per episode: 51.24
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.7      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 59600     |
# |    time_elapsed       | 698       |
# |    total_timesteps    | 298000    |
# | train/                |           |
# |    entropy_loss       | -0.0111   |
# |    explained_variance | -63.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59599     |
# |    policy_loss        | -0.000172 |
# |    value_loss         | 0.00699   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.7     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 59700    |
# |    time_elapsed       | 699      |
# |    total_timesteps    | 298500   |
# | train/                |          |
# |    entropy_loss       | -0.00797 |
# |    explained_variance | -67.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59699    |
# |    policy_loss        | 0.000194 |
# |    value_loss         | 0.0249   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.7      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 59800     |
# |    time_elapsed       | 700       |
# |    total_timesteps    | 299000    |
# | train/                |           |
# |    entropy_loss       | -0.0167   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59799     |
# |    policy_loss        | -3.75e-05 |
# |    value_loss         | 0.000306  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.7      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 59900     |
# |    time_elapsed       | 702       |
# |    total_timesteps    | 299500    |
# | train/                |           |
# |    entropy_loss       | -0.138    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59899     |
# |    policy_loss        | -3.83e-05 |
# |    value_loss         | 3.42e-06  |
# -------------------------------------
# Num timesteps: 299880
# Best mean reward: 67.87 - Last mean reward per episode: 52.49
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53        |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 60000     |
# |    time_elapsed       | 703       |
# |    total_timesteps    | 300000    |
# | train/                |           |
# |    entropy_loss       | -0.144    |
# |    explained_variance | -9.1      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59999     |
# |    policy_loss        | -0.000234 |
# |    value_loss         | 8.37e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53       |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 60100    |
# |    time_elapsed       | 704      |
# |    total_timesteps    | 300500   |
# | train/                |          |
# |    entropy_loss       | -0.14    |
# |    explained_variance | 0.222    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60099    |
# |    policy_loss        | 0.00507  |
# |    value_loss         | 0.00776  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53       |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 60200    |
# |    time_elapsed       | 705      |
# |    total_timesteps    | 301000   |
# | train/                |          |
# |    entropy_loss       | -0.405   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60199    |
# |    policy_loss        | -0.473   |
# |    value_loss         | 0.288    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53       |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 60300    |
# |    time_elapsed       | 706      |
# |    total_timesteps    | 301500   |
# | train/                |          |
# |    entropy_loss       | -0.501   |
# |    explained_variance | -202     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60299    |
# |    policy_loss        | -0.00467 |
# |    value_loss         | 0.000173 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53        |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 60400     |
# |    time_elapsed       | 707       |
# |    total_timesteps    | 302000    |
# | train/                |           |
# |    entropy_loss       | -0.000649 |
# |    explained_variance | -911      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60399     |
# |    policy_loss        | -1.66e-07 |
# |    value_loss         | 5.53e-05  |
# -------------------------------------
# Num timesteps: 302022
# Best mean reward: 67.87 - Last mean reward per episode: 52.48
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 60500    |
# |    time_elapsed       | 709      |
# |    total_timesteps    | 302500   |
# | train/                |          |
# |    entropy_loss       | -0.354   |
# |    explained_variance | -0.405   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60499    |
# |    policy_loss        | 0.0423   |
# |    value_loss         | 0.0107   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 60600    |
# |    time_elapsed       | 709      |
# |    total_timesteps    | 303000   |
# | train/                |          |
# |    entropy_loss       | -0.102   |
# |    explained_variance | -0.091   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60599    |
# |    policy_loss        | -0.00216 |
# |    value_loss         | 0.0108   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 60700    |
# |    time_elapsed       | 710      |
# |    total_timesteps    | 303500   |
# | train/                |          |
# |    entropy_loss       | -0.42    |
# |    explained_variance | -1.64    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60699    |
# |    policy_loss        | -0.00122 |
# |    value_loss         | 7.52e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.2      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 60800     |
# |    time_elapsed       | 711       |
# |    total_timesteps    | 304000    |
# | train/                |           |
# |    entropy_loss       | -0.0142   |
# |    explained_variance | -15.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60799     |
# |    policy_loss        | -1.97e-05 |
# |    value_loss         | 0.000113  |
# -------------------------------------
# Num timesteps: 304164
# Best mean reward: 67.87 - Last mean reward per episode: 50.46
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 60900    |
# |    time_elapsed       | 713      |
# |    total_timesteps    | 304500   |
# | train/                |          |
# |    entropy_loss       | -0.0367  |
# |    explained_variance | -1.55    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60899    |
# |    policy_loss        | 0.00171  |
# |    value_loss         | 0.0823   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 61000    |
# |    time_elapsed       | 714      |
# |    total_timesteps    | 305000   |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60999    |
# |    policy_loss        | -0.139   |
# |    value_loss         | 0.0302   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 61100     |
# |    time_elapsed       | 715       |
# |    total_timesteps    | 305500    |
# | train/                |           |
# |    entropy_loss       | -0.00142  |
# |    explained_variance | 0.143     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61099     |
# |    policy_loss        | -2.67e-06 |
# |    value_loss         | 0.000343  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 61200    |
# |    time_elapsed       | 716      |
# |    total_timesteps    | 306000   |
# | train/                |          |
# |    entropy_loss       | -0.262   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61199    |
# |    policy_loss        | -0.0445  |
# |    value_loss         | 0.88     |
# ------------------------------------
# Num timesteps: 306306
# Best mean reward: 67.87 - Last mean reward per episode: 50.90
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.7     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 61300    |
# |    time_elapsed       | 717      |
# |    total_timesteps    | 306500   |
# | train/                |          |
# |    entropy_loss       | -0.00103 |
# |    explained_variance | -8.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61299    |
# |    policy_loss        | 2.31e-06 |
# |    value_loss         | 0.00124  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.7      |
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 61400     |
# |    time_elapsed       | 718       |
# |    total_timesteps    | 307000    |
# | train/                |           |
# |    entropy_loss       | -0.00736  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61399     |
# |    policy_loss        | -2.71e-05 |
# |    value_loss         | 0.00105   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.7     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 61500    |
# |    time_elapsed       | 719      |
# |    total_timesteps    | 307500   |
# | train/                |          |
# |    entropy_loss       | -0.0291  |
# |    explained_variance | 0.0234   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61499    |
# |    policy_loss        | 0.00765  |
# |    value_loss         | 0.822    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.7      |
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 61600     |
# |    time_elapsed       | 720       |
# |    total_timesteps    | 308000    |
# | train/                |           |
# |    entropy_loss       | -0.264    |
# |    explained_variance | -35.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61599     |
# |    policy_loss        | -0.000594 |
# |    value_loss         | 0.000154  |
# -------------------------------------
# Num timesteps: 308448
# Best mean reward: 67.87 - Last mean reward per episode: 52.45
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.9     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 61700    |
# |    time_elapsed       | 721      |
# |    total_timesteps    | 308500   |
# | train/                |          |
# |    entropy_loss       | -0.253   |
# |    explained_variance | -0.0555  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61699    |
# |    policy_loss        | -0.00565 |
# |    value_loss         | 0.0374   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.9     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 61800    |
# |    time_elapsed       | 723      |
# |    total_timesteps    | 309000   |
# | train/                |          |
# |    entropy_loss       | -0.0706  |
# |    explained_variance | 0.631    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61799    |
# |    policy_loss        | -0.00037 |
# |    value_loss         | 0.000676 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.9     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 61900    |
# |    time_elapsed       | 723      |
# |    total_timesteps    | 309500   |
# | train/                |          |
# |    entropy_loss       | -0.124   |
# |    explained_variance | -0.0393  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61899    |
# |    policy_loss        | 0.00171  |
# |    value_loss         | 0.00632  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.9     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62000    |
# |    time_elapsed       | 724      |
# |    total_timesteps    | 310000   |
# | train/                |          |
# |    entropy_loss       | -0.0106  |
# |    explained_variance | -86.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61999    |
# |    policy_loss        | 9.37e-06 |
# |    value_loss         | 6.62e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.8     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62100    |
# |    time_elapsed       | 725      |
# |    total_timesteps    | 310500   |
# | train/                |          |
# |    entropy_loss       | -0.0147  |
# |    explained_variance | -3.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62099    |
# |    policy_loss        | 0.000186 |
# |    value_loss         | 0.00641  |
# ------------------------------------
# Num timesteps: 310590
# Best mean reward: 67.87 - Last mean reward per episode: 52.02
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.8      |
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 62200     |
# |    time_elapsed       | 727       |
# |    total_timesteps    | 311000    |
# | train/                |           |
# |    entropy_loss       | -0.0183   |
# |    explained_variance | -1.25     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62199     |
# |    policy_loss        | -7.74e-05 |
# |    value_loss         | 0.00104   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.8     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62300    |
# |    time_elapsed       | 728      |
# |    total_timesteps    | 311500   |
# | train/                |          |
# |    entropy_loss       | -0.117   |
# |    explained_variance | -7.57    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62299    |
# |    policy_loss        | -0.0024  |
# |    value_loss         | 0.0032   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.8     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62400    |
# |    time_elapsed       | 730      |
# |    total_timesteps    | 312000   |
# | train/                |          |
# |    entropy_loss       | -0.0873  |
# |    explained_variance | -0.0274  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62399    |
# |    policy_loss        | 0.818    |
# |    value_loss         | 2.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.4     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62500    |
# |    time_elapsed       | 731      |
# |    total_timesteps    | 312500   |
# | train/                |          |
# |    entropy_loss       | -0.286   |
# |    explained_variance | 0.344    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62499    |
# |    policy_loss        | -0.00437 |
# |    value_loss         | 0.00859  |
# ------------------------------------
# Num timesteps: 312732
# Best mean reward: 67.87 - Last mean reward per episode: 52.07
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.4      |
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 62600     |
# |    time_elapsed       | 732       |
# |    total_timesteps    | 313000    |
# | train/                |           |
# |    entropy_loss       | -0.115    |
# |    explained_variance | -34.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62599     |
# |    policy_loss        | -0.000989 |
# |    value_loss         | 0.00353   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.4     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62700    |
# |    time_elapsed       | 733      |
# |    total_timesteps    | 313500   |
# | train/                |          |
# |    entropy_loss       | -0.344   |
# |    explained_variance | 0.22     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62699    |
# |    policy_loss        | -0.0141  |
# |    value_loss         | 0.00514  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.4     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62800    |
# |    time_elapsed       | 734      |
# |    total_timesteps    | 314000   |
# | train/                |          |
# |    entropy_loss       | -0.132   |
# |    explained_variance | -0.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62799    |
# |    policy_loss        | -0.548   |
# |    value_loss         | 136      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.6     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 62900    |
# |    time_elapsed       | 735      |
# |    total_timesteps    | 314500   |
# | train/                |          |
# |    entropy_loss       | -0.252   |
# |    explained_variance | -2.76    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62899    |
# |    policy_loss        | 0.00792  |
# |    value_loss         | 0.00362  |
# ------------------------------------
# Num timesteps: 314874
# Best mean reward: 67.87 - Last mean reward per episode: 51.52
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 52.6      |
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 63000     |
# |    time_elapsed       | 736       |
# |    total_timesteps    | 315000    |
# | train/                |           |
# |    entropy_loss       | -0.00833  |
# |    explained_variance | -1.95     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62999     |
# |    policy_loss        | -3.69e-06 |
# |    value_loss         | 0.000993  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.6     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 63100    |
# |    time_elapsed       | 737      |
# |    total_timesteps    | 315500   |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | -0.00576 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63099    |
# |    policy_loss        | 0.0489   |
# |    value_loss         | 2.65     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 52.6     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 63200    |
# |    time_elapsed       | 738      |
# |    total_timesteps    | 316000   |
# | train/                |          |
# |    entropy_loss       | -0.151   |
# |    explained_variance | -3.81    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63199    |
# |    policy_loss        | -0.00449 |
# |    value_loss         | 0.000887 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.3     |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 63300    |
# |    time_elapsed       | 739      |
# |    total_timesteps    | 316500   |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | -7.66    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63299    |
# |    policy_loss        | -0.0144  |
# |    value_loss         | 0.00101  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.3      |
# | time/                 |           |
# |    fps                | 428       |
# |    iterations         | 63400     |
# |    time_elapsed       | 740       |
# |    total_timesteps    | 317000    |
# | train/                |           |
# |    entropy_loss       | -0.047    |
# |    explained_variance | 0.122     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 63399     |
# |    policy_loss        | -0.000292 |
# |    value_loss         | 0.000508  |
# -------------------------------------
# Num timesteps: 317016
# Best mean reward: 67.87 - Last mean reward per episode: 51.71
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.3     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 63500    |
# |    time_elapsed       | 742      |
# |    total_timesteps    | 317500   |
# | train/                |          |
# |    entropy_loss       | -0.285   |
# |    explained_variance | 0.495    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63499    |
# |    policy_loss        | -0.00113 |
# |    value_loss         | 0.00016  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.3     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 63600    |
# |    time_elapsed       | 743      |
# |    total_timesteps    | 318000   |
# | train/                |          |
# |    entropy_loss       | -0.11    |
# |    explained_variance | -0.00594 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63599    |
# |    policy_loss        | -0.0477  |
# |    value_loss         | 4.57     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.6     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 63700    |
# |    time_elapsed       | 744      |
# |    total_timesteps    | 318500   |
# | train/                |          |
# |    entropy_loss       | -0.0536  |
# |    explained_variance | 0.0412   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63699    |
# |    policy_loss        | -0.00229 |
# |    value_loss         | 0.0889   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.6     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 63800    |
# |    time_elapsed       | 745      |
# |    total_timesteps    | 319000   |
# | train/                |          |
# |    entropy_loss       | -0.048   |
# |    explained_variance | -0.148   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63799    |
# |    policy_loss        | 0.00206  |
# |    value_loss         | 0.0625   |
# ------------------------------------
# Num timesteps: 319158
# Best mean reward: 67.87 - Last mean reward per episode: 50.73
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.6     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 63900    |
# |    time_elapsed       | 746      |
# |    total_timesteps    | 319500   |
# | train/                |          |
# |    entropy_loss       | -0.111   |
# |    explained_variance | 6.53e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63899    |
# |    policy_loss        | -0.00375 |
# |    value_loss         | 0.343    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.6     |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 64000    |
# |    time_elapsed       | 747      |
# |    total_timesteps    | 320000   |
# | train/                |          |
# |    entropy_loss       | -0.192   |
# |    explained_variance | 0.612    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63999    |
# |    policy_loss        | 0.00988  |
# |    value_loss         | 0.00849  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 54.5      |
# | time/                 |           |
# |    fps                | 428       |
# |    iterations         | 64100     |
# |    time_elapsed       | 748       |
# |    total_timesteps    | 320500    |
# | train/                |           |
# |    entropy_loss       | -0.000763 |
# |    explained_variance | -0.476    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64099     |
# |    policy_loss        | 1.07e-06  |
# |    value_loss         | 0.0047    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 54.5      |
# | time/                 |           |
# |    fps                | 428       |
# |    iterations         | 64200     |
# |    time_elapsed       | 749       |
# |    total_timesteps    | 321000    |
# | train/                |           |
# |    entropy_loss       | -0.00329  |
# |    explained_variance | 0.368     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64199     |
# |    policy_loss        | -1.44e-05 |
# |    value_loss         | 0.00138   |
# -------------------------------------
# Num timesteps: 321300
# Best mean reward: 67.87 - Last mean reward per episode: 52.50
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 54.5      |
# | time/                 |           |
# |    fps                | 428       |
# |    iterations         | 64300     |
# |    time_elapsed       | 750       |
# |    total_timesteps    | 321500    |
# | train/                |           |
# |    entropy_loss       | -0.00645  |
# |    explained_variance | -8.72     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64299     |
# |    policy_loss        | -6.15e-06 |
# |    value_loss         | 0.000315  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# ...
# |    n_updates          | 83199    |
# |    policy_loss        | 5.39e-05 |
# |    value_loss         | 0.0942   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 54.1      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 83300     |
# |    time_elapsed       | 963       |
# |    total_timesteps    | 416500    |
# | train/                |           |
# |    entropy_loss       | -0.0717   |
# |    explained_variance | -0.532    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83299     |
# |    policy_loss        | -0.000432 |
# |    value_loss         | 0.00109   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 54.1     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 83400    |
# |    time_elapsed       | 964      |
# |    total_timesteps    | 417000   |
# | train/                |          |
# |    entropy_loss       | -0.00287 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 83399    |
# |    policy_loss        | 5.45e-07 |
# |    value_loss         | 3.6e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 54.1      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 83500     |
# |    time_elapsed       | 965       |
# |    total_timesteps    | 417500    |
# | train/                |           |
# |    entropy_loss       | -0.00019  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83499     |
# |    policy_loss        | -2.36e-07 |
# |    value_loss         | 0.000155  |
# -------------------------------------
# Num timesteps: 417690
# Best mean reward: 67.87 - Last mean reward per episode: 60.98
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.9     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 83600    |
# |    time_elapsed       | 966      |
# |    total_timesteps    | 418000   |
# | train/                |          |
# |    entropy_loss       | -0.325   |
# |    explained_variance | 0.476    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 83599    |
# |    policy_loss        | 0.0437   |
# |    value_loss         | 0.0343   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.9      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 83700     |
# |    time_elapsed       | 967       |
# |    total_timesteps    | 418500    |
# | train/                |           |
# |    entropy_loss       | -0.117    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83699     |
# |    policy_loss        | -0.000959 |
# |    value_loss         | 0.00161   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.9      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 83800     |
# |    time_elapsed       | 968       |
# |    total_timesteps    | 419000    |
# | train/                |           |
# |    entropy_loss       | -0.000189 |
# |    explained_variance | -11.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83799     |
# |    policy_loss        | -7.37e-08 |
# |    value_loss         | 0.000223  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.9      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 83900     |
# |    time_elapsed       | 969       |
# |    total_timesteps    | 419500    |
# | train/                |           |
# |    entropy_loss       | -0.0396   |
# |    explained_variance | -9.79     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83899     |
# |    policy_loss        | -0.000235 |
# |    value_loss         | 0.00084   |
# -------------------------------------
# Num timesteps: 419832
# Best mean reward: 67.87 - Last mean reward per episode: 61.99
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.7     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 84000    |
# |    time_elapsed       | 970      |
# |    total_timesteps    | 420000   |
# | train/                |          |
# |    entropy_loss       | -0.0154  |
# |    explained_variance | 0.302    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 83999    |
# |    policy_loss        | -0.00013 |
# |    value_loss         | 0.00222  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.7      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 84100     |
# |    time_elapsed       | 972       |
# |    total_timesteps    | 420500    |
# | train/                |           |
# |    entropy_loss       | -0.0449   |
# |    explained_variance | -2.09     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84099     |
# |    policy_loss        | -0.000289 |
# |    value_loss         | 0.00173   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.7      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 84200     |
# |    time_elapsed       | 973       |
# |    total_timesteps    | 421000    |
# | train/                |           |
# |    entropy_loss       | -4.83e-05 |
# |    explained_variance | -17.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84199     |
# |    policy_loss        | -2.1e-07  |
# |    value_loss         | 0.00294   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.7     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 84300    |
# |    time_elapsed       | 975      |
# |    total_timesteps    | 421500   |
# | train/                |          |
# |    entropy_loss       | -0.18    |
# |    explained_variance | -72.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84299    |
# |    policy_loss        | -0.00438 |
# |    value_loss         | 0.000546 |
# ------------------------------------
# Num timesteps: 421974
# Best mean reward: 67.87 - Last mean reward per episode: 60.57
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.3     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 84400    |
# |    time_elapsed       | 976      |
# |    total_timesteps    | 422000   |
# | train/                |          |
# |    entropy_loss       | -0.112   |
# |    explained_variance | 0.474    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84399    |
# |    policy_loss        | 0.00414  |
# |    value_loss         | 0.0661   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.3     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 84500    |
# |    time_elapsed       | 977      |
# |    total_timesteps    | 422500   |
# | train/                |          |
# |    entropy_loss       | -0.244   |
# |    explained_variance | -0.373   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84499    |
# |    policy_loss        | 0.00095  |
# |    value_loss         | 0.173    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.3      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 84600     |
# |    time_elapsed       | 978       |
# |    total_timesteps    | 423000    |
# | train/                |           |
# |    entropy_loss       | -0.00602  |
# |    explained_variance | 0.0475    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84599     |
# |    policy_loss        | -8.33e-05 |
# |    value_loss         | 0.0353    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.3      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 84700     |
# |    time_elapsed       | 979       |
# |    total_timesteps    | 423500    |
# | train/                |           |
# |    entropy_loss       | -0.0163   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84699     |
# |    policy_loss        | -0.000494 |
# |    value_loss         | 0.023     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 84800    |
# |    time_elapsed       | 980      |
# |    total_timesteps    | 424000   |
# | train/                |          |
# |    entropy_loss       | -0.128   |
# |    explained_variance | -1.24    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84799    |
# |    policy_loss        | -0.00109 |
# |    value_loss         | 0.016    |
# ------------------------------------
# Num timesteps: 424116
# Best mean reward: 67.87 - Last mean reward per episode: 59.21
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 84900    |
# |    time_elapsed       | 981      |
# |    total_timesteps    | 424500   |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | -2.27    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84899    |
# |    policy_loss        | 0.000107 |
# |    value_loss         | 0.000297 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 85000    |
# |    time_elapsed       | 982      |
# |    total_timesteps    | 425000   |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | -0.00645 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84999    |
# |    policy_loss        | -0.045   |
# |    value_loss         | 0.0153   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.2      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 85100     |
# |    time_elapsed       | 983       |
# |    total_timesteps    | 425500    |
# | train/                |           |
# |    entropy_loss       | -0.0168   |
# |    explained_variance | -55.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 85099     |
# |    policy_loss        | -0.000162 |
# |    value_loss         | 0.00283   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 85200     |
# |    time_elapsed       | 984       |
# |    total_timesteps    | 426000    |
# | train/                |           |
# |    entropy_loss       | -0.00334  |
# |    explained_variance | 0.747     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 85199     |
# |    policy_loss        | -1.19e-05 |
# |    value_loss         | 0.000993  |
# -------------------------------------
# Num timesteps: 426258
# Best mean reward: 67.87 - Last mean reward per episode: 58.38
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 85300     |
# |    time_elapsed       | 985       |
# |    total_timesteps    | 426500    |
# | train/                |           |
# |    entropy_loss       | -0.0143   |
# |    explained_variance | -0.462    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 85299     |
# |    policy_loss        | -3.75e-05 |
# |    value_loss         | 0.000608  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 85400    |
# |    time_elapsed       | 987      |
# |    total_timesteps    | 427000   |
# | train/                |          |
# |    entropy_loss       | -0.141   |
# |    explained_variance | -0.0171  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 85399    |
# |    policy_loss        | 0.114    |
# |    value_loss         | 0.929    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.03e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 85500    |
# |    time_elapsed       | 988      |
# |    total_timesteps    | 427500   |
# | train/                |          |
# |    entropy_loss       | -0.0261  |
# |    explained_variance | -40.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 85499    |
# |    policy_loss        | 0.0357   |
# |    value_loss         | 0.000989 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.03e+03  |
# |    ep_rew_mean        | 53        |
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 85600     |
# |    time_elapsed       | 989       |
# |    total_timesteps    | 428000    |
# | train/                |           |
# |    entropy_loss       | -0.127    |
# |    explained_variance | 0.593     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 85599     |
# |    policy_loss        | -0.000305 |
# |    value_loss         | 8.01e-05  |
# -------------------------------------
# Num timesteps: 428400
# Best mean reward: 67.87 - Last mean reward per episode: 58.38

# %%
from stable_baselines3.common import results_plotter

# Helper from the library
results_plotter.plot_results(
    [log_dir], 1e5, results_plotter.X_TIMESTEPS, "Gym Any Trading"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=14)
    # Truncate x
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_results(log_dir)

# %% [markdown]
# ### 6. Evaluate the model

# %%
total_profit_list = []
total_reward_list = []
total_sharpe_ratio_list = []

for i in range(5):

  env = MyCustomEnv(df=test_df, frame_bound=(WINDOW_SIZE, len(test_df)), window_size=WINDOW_SIZE)

  observation, info = env.reset(seed=2024)
  while True:
      action = model.predict(observation)
      observation, reward, terminated, truncated, info = env.step(action[0])
      done = terminated or truncated

      if done:
          print("info:", info)
          total_profit_list.append(info['total_profit'])
          total_reward_list.append(info['total_reward'])
          break

  plt.cla()
  env.unwrapped.render_all()
  plt.show()

  AWR = env.history['total_profit']

  average_sharpe_ratio = np.mean(AWR) / np.std(AWR)
  print('Sharpe Ratio:', average_sharpe_ratio)
  total_sharpe_ratio_list.append(average_sharpe_ratio)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# info: {'total_reward': 140.199884, 'total_profit': 1096.4625734671351, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 4.901004976937944
# info: {'total_reward': 133.86391300000003, 'total_profit': 1095.3933781442881, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 4.849640008629496
# info: {'total_reward': 143.40588199999996, 'total_profit': 1113.0497213386639, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 4.538962660900282
# info: {'total_reward': 127.54591400000004, 'total_profit': 1014.5335899508244, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 6.121283784910928
# info: {'total_reward': 179.07796300000007, 'total_profit': 1189.3185226495184, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 4.5115088113784365

# %%
print('average sharpe ratio: ',np.mean(total_sharpe_ratio_list))
print('average profit: ',np.mean(total_profit_list))
# Out:
# average sharpe ratio:  4.984480048551418
# average profit:  1101.751557110086
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
