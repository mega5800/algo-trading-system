# %% [markdown]
# # With Technical Indicators Version

# %% [markdown]
# In this version, the agent uses close price value, the difference in close prices from the previous trading day, and 8 technical indicators as the state for predicting actions (buy or sell). The parameters for this baseline version are as follows:
#
# WINDOW_SIZE: 14
# train_df: 2142
# test_df: 814
# total_timesteps: 428,400
# episodes: 200

# %% [markdown]
# ## WithTechIndicators

# %% [markdown]
# ### Pip Install Commands

# %%
# !pip install gymnasium gym-anytrading pandas matplotlib stable-baselines3[extra] finta
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: gym-anytrading in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: finta in /usr/local/lib/python3.10/dist-packages (1.3)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.4.0+cu121)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.8.0)
# Requirement already satisfied: shimmy~=1.3.0 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: autorom~=0.6.1 in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.32.3)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (71.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.4.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)

# %% [markdown]
# ### Libraries

# %%
import gymnasium as gym
import gym_anytrading
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

from gym_anytrading.envs import Positions
from gym_anytrading.envs import StocksEnv
from finta import TA

from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback

# %% [markdown]
# ### Constant Values

# %%
WINDOW_SIZE = 14
DATASET_PATH = '/content/TSLA.csv'

# %% [markdown]
# ### Methods

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            # print('y',y)
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-14:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    diff = np.insert(np.diff(prices), 0, 0)
    signal_features = env.df.loc[:, ['Close','SMA', 'RSI', 'MOM', 'OBV', 'EMA', 'Stochastic oscillator', 'AD', 'ROC']].to_numpy()[start:end]
    # Reshape diff to (282, 1)
    diff_reshaped = diff.reshape(len(diff), 1)

    # Concatenate along the second axis (columns)
    signal_features = np.concatenate((signal_features, diff_reshaped), axis=1)


    return prices, signal_features

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals

    def reset(self, seed=None, options=None):
      super().reset(seed=seed, options=options)
      self.action_space.seed(int((self.np_random.uniform(0, seed if seed is not None else 1))))

      self._truncated = False
      self._current_tick = self._start_tick
      self._last_trade_tick = self._current_tick - 1
      self._position = Positions.Short
      self._position_history = (self.window_size * [None]) + [self._position]
      self._total_reward = 0.
      self._total_profit = 1000.  # unit
      self._first_rendering = True
      self.history = {}

      observation = self._get_observation()
      info = self._get_info()

      if self.render_mode == 'human':
          self._render_frame()

      return observation, info

# %%
def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=14)
    # Truncate x
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()

# %% [markdown]
# ### Code

# %% [markdown]
# Read and prepare the dataset

# %%
df = pd.read_csv(DATASET_PATH)

# %%
df['Date'] = pd.to_datetime(df.Date)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df.set_index('Date', inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2956 entries, 2010-06-29 to 2022-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2956 non-null   float64
#  1   High       2956 non-null   float64
#  2   Low        2956 non-null   float64
#  3   Close      2956 non-null   float64
#  4   Adj Close  2956 non-null   float64
#  5   Volume     2956 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 161.7 KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['SMA'] = TA.SMA(df, WINDOW_SIZE)
df['RSI'] = TA.RSI(df, WINDOW_SIZE)
df['MOM'] = TA.MOM(df, WINDOW_SIZE)
df['OBV'] = TA.OBV(df,'close')
df['EMA'] = TA.EMA(df, WINDOW_SIZE)
df['Stochastic oscillator'] = TA.AO(df,WINDOW_SIZE)
df['AD'] = TA.ADL(df)
df['ROC'] = TA.ROC(df,WINDOW_SIZE)
df.fillna(0, inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(50)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              Open   High    Low  Close  Adj Close    Volume       SMA  \
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500  0.000000
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500  0.000000
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000  0.000000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000  0.000000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500  0.000000
# 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500  0.000000
# 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000  0.000000
# 2010-07-09  3.516  3.580  3.310  3.480      3.480  20253000  0.000000
# 2010-07-12  3.590  3.614  3.400  3.410      3.410  11012500  0.000000
# 2010-07-13  3.478  3.728  3.380  3.628      3.628  13400500  0.000000
# 2010-07-14  3.588  4.030  3.552  3.968      3.968  20976000  0.000000
# 2010-07-15  3.988  4.300  3.800  3.978      3.978  18699000  0.000000
# 2010-07-16  4.140  4.260  4.010  4.128      4.128  13106500  0.000000
# 2010-07-19  4.274  4.450  4.184  4.382      4.382  12432500  3.901714
# 2010-07-20  4.370  4.370  4.010  4.060      4.060   9126500  3.850429
# 2010-07-21  4.132  4.180  3.900  4.044      4.044   6262500  3.798857
# 2010-07-22  4.100  4.250  4.074  4.200      4.200   4789000  3.785143
# 2010-07-23  4.238  4.312  4.212  4.258      4.258   3268000  3.815000
# 2010-07-26  4.300  4.300  4.060  4.190      4.190   4611000  3.884143
# 2010-07-27  4.182  4.236  4.052  4.110      4.110   3098500  3.952000
# 2010-07-28  4.110  4.180  4.102  4.144      4.144   2336000  3.998571
# 2010-07-29  4.154  4.176  4.000  4.070      4.070   3080000  4.040714
# 2010-07-30  4.040  4.088  3.910  3.988      3.988   2134500  4.082000
# 2010-08-02  4.100  4.194  4.066  4.184      4.184   3590500  4.121714
# 2010-08-03  4.200  4.390  4.164  4.390      4.390   6152500  4.151857
# 2010-08-04  4.390  4.436  4.170  4.252      4.252   4565000  4.171429
# 2010-08-05  4.308  4.310  4.010  4.090      4.090   3981000  4.168714
# 2010-08-06  4.020  4.032  3.904  3.918      3.918   3709500  4.135571
# 2010-08-09  3.980  3.996  3.890  3.920      3.920   4063500  4.125571
# 2010-08-10  3.930  3.930  3.764  3.806      3.806   6406500  4.108571
# 2010-08-11  3.738  3.776  3.570  3.580      3.580   3988000  4.064286
# 2010-08-12  3.560  3.580  3.478  3.520      3.520   3455000  4.011571
# 2010-08-13  3.636  3.690  3.532  3.664      3.664   3170000  3.974000
# 2010-08-16  3.690  3.760  3.652  3.756      3.756   2429000  3.948714
# 2010-08-17  3.792  3.880  3.756  3.830      3.830   2239500  3.926286
# 2010-08-18  3.918  3.918  3.720  3.754      3.754   3006500  3.903714
# 2010-08-19  3.708  3.850  3.666  3.758      3.758   2895500  3.887286
# 2010-08-20  3.730  3.822  3.702  3.820      3.820   1480000  3.861286
# 2010-08-23  3.818  4.078  3.800  4.026      4.026   5440500  3.835286
# 2010-08-24  3.850  3.942  3.790  3.840      3.840   3365500  3.805857
# 2010-08-25  3.832  3.996  3.712  3.980      3.980   2516500  3.798000
# 2010-08-26  3.978  4.054  3.920  3.950      3.950   2169000  3.800286
# 2010-08-27  3.950  3.974  3.900  3.940      3.940   1898000  3.801714
# 2010-08-30  3.940  4.038  3.922  3.974      3.974   3664000  3.813714
# 2010-08-31  3.932  3.958  3.866  3.896      3.896   1005500  3.836286
# 2010-09-01  3.924  4.138  3.920  4.090      4.090   2474500  3.877000
# 2010-09-02  4.074  4.248  4.062  4.212      4.212   2435500  3.916143
# 2010-09-03  4.174  4.260  4.132  4.210      4.210   2173000  3.948571
# 2010-09-07  4.122  4.200  4.100  4.108      4.108   1217000  3.968429
# 2010-09-08  4.132  4.190  4.120  4.180      4.180   1442000  3.998857
#
#                   RSI    MOM          OBV       EMA  Stochastic oscillator  \
# Date
# 2010-06-29   0.000000  0.000          0.0  4.778000               0.000000
# 2010-06-30   0.000000  0.000  -85935500.0  4.771571               0.000000
# 2010-07-01   0.000000  0.000 -127029500.0  4.626574               0.000000
# 2010-07-02   0.000000  0.000 -152728500.0  4.385939               0.000000
# 2010-07-06   0.000000  0.000 -187063000.0  4.082269               0.000000
# 2010-07-07   0.000000  0.000 -221671500.0  3.868872               0.000000
# 2010-07-08  20.112173  0.000 -183114500.0  3.789457               0.000000
# 2010-07-09  19.955945  0.000 -203367500.0  3.728932               0.000000
# 2010-07-12  19.027444  0.000 -214380000.0  3.670209               0.000000
# 2010-07-13  29.957330  0.000 -200979500.0  3.662813               0.000000
# 2010-07-14  42.902359  0.000 -180003500.0  3.714139               0.000000
# 2010-07-15  43.234658  0.000 -161304500.0  3.757021               0.000000
# 2010-07-16  48.112728  0.000 -148198000.0  3.815601               0.000000
# 2010-07-19  55.142300  0.000 -135765500.0  3.902895               0.020971
# 2010-07-20  46.535206 -0.718 -144892000.0  3.926615               0.152743
# 2010-07-21  46.149737 -0.722 -151154500.0  3.944030               0.297686
# 2010-07-22  50.458627 -0.192 -146365500.0  3.981445               0.352729
# 2010-07-23  51.996562  0.418 -143097500.0  4.021355               0.372343
# 2010-07-26  50.035402  0.968 -147708500.0  4.045429               0.302300
# 2010-07-27  47.753439  0.950 -150807000.0  4.054560               0.222886
# 2010-07-28  48.821732  0.652 -148471000.0  4.067107               0.183657
# 2010-07-29  46.588916  0.590 -151551000.0  4.067510               0.122929
# 2010-07-30  44.177840  0.578 -153685500.0  4.056499               0.035186
# 2010-08-02  50.740038  0.556 -150095000.0  4.074066              -0.015957
# 2010-08-03  56.524737  0.422 -143942500.0  4.117401              -0.024071
# 2010-08-04  52.110005  0.274 -148507500.0  4.135793              -0.009743
# 2010-08-05  47.427123 -0.038 -152488500.0  4.129557               0.002871
# 2010-08-06  43.007969 -0.464 -156198000.0  4.100826               0.021600
# 2010-08-09  43.074390 -0.140 -152134500.0  4.076330               0.001843
# 2010-08-10  40.198567 -0.238 -158541000.0  4.039787              -0.070371
# 2010-08-11  35.183563 -0.620 -162529000.0  3.977747              -0.161443
# 2010-08-12  33.971830 -0.738 -165984000.0  3.916081              -0.235286
# 2010-08-13  39.368907 -0.526 -162814000.0  3.882169              -0.266043
# 2010-08-16  42.597196 -0.354 -160385000.0  3.865216              -0.282157
# 2010-08-17  45.127988 -0.314 -158145500.0  3.860489              -0.264886
# 2010-08-18  43.029732 -0.316 -161152000.0  3.846207              -0.216471
# 2010-08-19  43.179475 -0.230 -158256500.0  3.834387              -0.153457
# 2010-08-20  45.567693 -0.364 -156776500.0  3.832460              -0.096971
# 2010-08-23  52.683745 -0.364 -151336000.0  3.858363              -0.026229
# 2010-08-24  46.741926 -0.412 -154701500.0  3.855907               0.014586
# 2010-08-25  51.202965 -0.110 -152185000.0  3.872500               0.043443
# 2010-08-26  50.231988  0.032 -154354000.0  3.882858               0.087886
# 2010-08-27  49.892354  0.020 -156252000.0  3.890494               0.123314
# 2010-08-30  51.102890  0.168 -152588000.0  3.901648               0.122014
# 2010-08-31  48.224550  0.316 -153593500.0  3.900894               0.114143
# 2010-09-01  55.011708  0.570 -151119000.0  3.926143               0.113429
# 2010-09-02  58.680025  0.548 -148683500.0  3.964303               0.108171
# 2010-09-03  58.595674  0.454 -150856500.0  3.997097               0.124971
# 2010-09-07  54.308051  0.278 -152073500.0  4.011897               0.135257
# 2010-09-08  56.715728  0.426 -150631500.0  4.034328               0.159857
#
#                       AD        ROC
# Date
# 2010-06-29  6.590845e+07   0.000000
# 2010-06-30 -7.233279e+06   0.000000
# 2010-07-01 -2.374361e+07   0.000000
# 2010-07-02 -4.370570e+07   0.000000
# 2010-07-06 -7.342934e+07   0.000000
# 2010-07-07 -7.363909e+07   0.000000
# 2010-07-08 -3.745482e+07   0.000000
# 2010-07-09 -3.220405e+07   0.000000
# 2010-07-12 -4.218734e+07   0.000000
# 2010-07-13 -3.648828e+07   0.000000
# 2010-07-14 -2.095375e+07   0.000000
# 2010-07-15 -2.633906e+07   0.000000
# 2010-07-16 -2.707303e+07   0.000000
# 2010-07-19 -2.099699e+07   0.000000
# 2010-07-20 -2.758835e+07 -15.027208
# 2010-07-21 -2.740942e+07 -15.148972
# 2010-07-22 -2.534145e+07  -4.371585
# 2010-07-23 -2.560289e+07  10.885417
# 2010-07-26 -2.521864e+07  30.043451
# 2010-07-27 -2.636374e+07  30.063291
# 2010-07-28 -2.618404e+07  18.671249
# 2010-07-29 -2.681404e+07  16.954023
# 2010-07-30 -2.707786e+07  16.950147
# 2010-08-02 -2.404837e+07  15.325248
# 2010-08-03 -1.789587e+07  10.635081
# 2010-08-04 -1.964636e+07   6.887883
# 2010-08-05 -2.150416e+07  -0.920543
# 2010-08-06 -2.440221e+07 -10.588772
# 2010-08-09 -2.616561e+07  -3.448276
# 2010-08-10 -2.933027e+07  -5.885262
# 2010-08-11 -3.293109e+07 -14.761905
# 2010-08-12 -3.354079e+07 -17.332081
# 2010-08-13 -3.141408e+07 -12.553699
# 2010-08-16 -2.916501e+07  -8.613139
# 2010-08-17 -2.873156e+07  -7.577220
# 2010-08-18 -3.070552e+07  -7.764128
# 2010-08-19 -3.070552e+07  -5.767302
# 2010-08-20 -2.927486e+07  -8.699809
# 2010-08-23 -2.586965e+07  -8.291572
# 2010-08-24 -2.702101e+07  -9.689558
# 2010-08-25 -2.478806e+07  -2.689487
# 2010-08-26 -2.598586e+07   0.816743
# 2010-08-27 -2.583197e+07   0.510204
# 2010-08-30 -2.621100e+07   4.414083
# 2010-08-31 -2.656074e+07   8.826816
# 2010-09-01 -2.517593e+07  16.193182
# 2010-09-02 -2.368321e+07  14.956332
# 2010-09-03 -2.320786e+07  12.087327
# 2010-09-07 -2.423014e+07   7.258486
# 2010-09-08 -2.320014e+07  11.347896

# %% [markdown]
# Split the dataset for training and testing

# %%
train_df = df.loc[df.index < '2019-01-01']
test_df = df.loc[df.index >= '2019-01-01']

print('train_df: ',len(train_df))
print('test_df: ',len(test_df))
# Out:
# train_df:  2142
# test_df:  814

# %%
train_df.shape
# Out:
# (2142, 14)

# %% [markdown]
# Create a log directory

# %%
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# %% [markdown]
# Create a trading environment for the agent to train on

# %%
env = MyCustomEnv(df=train_df, frame_bound=(WINDOW_SIZE, len(train_df)), window_size=WINDOW_SIZE)

env = Monitor(env, log_dir)

# %% [markdown]
# A vector the agent will use to predict the action (buy or sell)

# %%
env.signal_features[:1,:]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.signal_features to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.signal_features` for environment variables or `env.get_wrapper_attr('signal_features')` that will search the reminding wrappers.
#   logger.warn(
# array([[4.77800000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.77800000e+00, 0.00000000e+00, 6.59084531e+07,
#         0.00000000e+00, 0.00000000e+00]])

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# Discrete: describes a discrete space where {0, 1, …, n-1} are the possible values our observation or action can take. Values can be shifted to {a, a+1, …, a+n-1} using an optional argument.

# %%
env.action_space.sample()
# Out:
# 0

# %% [markdown]
# Sell = 0
#
# Buy = 1

# %%
env.observation_space
# Out:
# Box(-10000000000.0, 10000000000.0, (14, 10), float32)

# %% [markdown]
# Box: describes an n-dimensional continuous space. It’s a bounded space where we can define the upper and lower limits which describe the valid values our observations can take.

# %%
env.observation_space.sample()
# Out:
# array([[ 7.7124598e+09, -4.8432732e+09,  5.0194217e+09,  6.2939781e+09,
#          8.6825646e+09, -3.5172813e+09, -1.0053671e+09,  3.8093648e+08,
#         -5.0212705e+09,  2.2277642e+09],
#        [ 2.8612792e+09,  8.3618063e+09, -5.7551345e+09, -7.3860157e+09,
#         -6.6868193e+09,  5.0261473e+09,  8.6668882e+09, -7.5835453e+09,
#          4.6957138e+09, -7.4349926e+09],
#        [ 6.5533297e+09, -3.5391905e+09, -6.5008378e+08, -8.4845032e+07,
#          7.8577357e+09, -7.2906281e+09,  9.3926216e+09, -6.0589696e+09,
#          4.5988142e+09, -6.7021210e+09],
#        [ 6.4738847e+09,  6.0167009e+09, -2.7958928e+08, -7.5454330e+08,
#          7.9632573e+09,  2.1113347e+09, -9.3217352e+09, -7.7836314e+09,
#         -8.7072952e+09, -5.9478630e+09],
#        [-7.2364662e+09,  8.6166815e+09,  4.9681101e+09,  5.7304904e+09,
#          6.5735235e+09, -1.4990964e+09,  1.6984774e+09,  1.1110243e+09,
#          1.7365101e+09,  2.1520699e+09],
#        [-4.1106854e+09, -7.9053353e+09,  9.4620344e+09,  2.4332096e+09,
#         -4.2675228e+09, -4.1157980e+09, -5.7763820e+09, -9.8921738e+09,
#         -8.6789434e+08, -9.9768207e+09],
#        [-9.1451668e+09, -2.2925233e+09,  9.4633452e+09,  7.8127068e+09,
#         -2.2106683e+09, -8.4198175e+09,  3.1590505e+09,  5.5155860e+09,
#         -2.0843281e+09,  4.2405553e+09],
#        [ 3.0938422e+09,  2.0252910e+09,  4.2930022e+09, -7.7231073e+09,
#         -6.0362122e+09,  6.9498752e+09, -9.5345357e+09,  5.7447142e+09,
#         -2.4945244e+09,  7.0381942e+09],
#        [ 9.7424353e+09,  4.5261507e+09, -9.9183022e+09,  6.1897989e+09,
#         -3.8993592e+09, -5.1798794e+09, -6.0856387e+09,  9.1874171e+09,
#          9.1788831e+09,  6.7062113e+09],
#        [-7.2432174e+09, -2.8717780e+09, -7.1208525e+09,  8.1882122e+09,
#          3.7504988e+09, -4.2731197e+09, -3.4367273e+09,  8.2123663e+09,
#         -7.9584046e+09, -7.2357038e+09],
#        [ 2.5277975e+09, -3.8185303e+09, -2.4060073e+09,  6.1727892e+09,
#          8.9273632e+08, -8.1649853e+09, -9.4584023e+09,  1.5071186e+09,
#         -8.9160172e+09,  9.6083579e+09],
#        [-8.3554017e+09,  5.4302861e+08, -5.3325960e+06, -1.5301670e+09,
#          4.9571236e+09,  3.8458486e+09, -3.4172883e+08,  9.1165624e+09,
#          9.3281382e+09, -5.3620106e+09],
#        [-5.4861069e+08, -1.7372966e+09, -5.4171725e+09,  6.3307121e+09,
#          6.1500370e+09, -6.4380851e+09, -6.2800026e+08,  3.2244998e+08,
#          8.2115871e+09, -5.1564897e+09],
#        [-6.3734548e+09, -9.5469087e+09, -7.1930875e+09,  2.7155579e+09,
#          7.9735107e+09, -2.7825664e+08, -3.2698025e+09,  6.6492324e+09,
#         -6.7767972e+09, -8.9293486e+09]], dtype=float32)

# %% [markdown]
# Create the environment and some random action on it

# %%
observation = env.reset(seed=2024)
while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    # env.render()
    if done:
        print("info:", info)
        break

plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info: {'total_reward': 61.0199479999999, 'total_profit': 4.17852559897671, 'position': <Positions.Short: 0>, 'episode': {'r': 61.019948, 'l': 2127, 't': 0.15976}}

# %% [markdown]
# Create and training the model for 200 episodes or epochs

# %%
model = A2C("MlpPolicy", env, verbose=1)

# Create the callback: check every 2142 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=2142, log_dir=log_dir)

# Train the model
model.learn(total_timesteps=428400,callback=callback)
# Out:
# Streaming output truncated to the last 5000 lines.
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 57100    |
# |    time_elapsed       | 590      |
# |    total_timesteps    | 285500   |
# | train/                |          |
# |    entropy_loss       | -0.198   |
# |    explained_variance | -0.295   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57099    |
# |    policy_loss        | 0.00628  |
# |    value_loss         | 0.0615   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.1     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 57200    |
# |    time_elapsed       | 591      |
# |    total_timesteps    | 286000   |
# | train/                |          |
# |    entropy_loss       | -0.128   |
# |    explained_variance | 0.0256   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57199    |
# |    policy_loss        | -1.31    |
# |    value_loss         | 29.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.1     |
# | time/                 |          |
# |    fps                | 482      |
# |    iterations         | 57300    |
# |    time_elapsed       | 593      |
# |    total_timesteps    | 286500   |
# | train/                |          |
# |    entropy_loss       | -0.373   |
# |    explained_variance | 0.0168   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57299    |
# |    policy_loss        | -0.101   |
# |    value_loss         | 0.07     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.1      |
# | time/                 |           |
# |    fps                | 482       |
# |    iterations         | 57400     |
# |    time_elapsed       | 594       |
# |    total_timesteps    | 287000    |
# | train/                |           |
# |    entropy_loss       | -0.00897  |
# |    explained_variance | -2.87     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 57399     |
# |    policy_loss        | -1.68e-05 |
# |    value_loss         | 0.000119  |
# -------------------------------------
# Num timesteps: 287028
# Best mean reward: 61.66 - Last mean reward per episode: 60.36
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.4      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 57500     |
# |    time_elapsed       | 595       |
# |    total_timesteps    | 287500    |
# | train/                |           |
# |    entropy_loss       | -0.000142 |
# |    explained_variance | -5.71e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 57499     |
# |    policy_loss        | 5.4e-07   |
# |    value_loss         | 0.00335   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.4      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 57600     |
# |    time_elapsed       | 596       |
# |    total_timesteps    | 288000    |
# | train/                |           |
# |    entropy_loss       | -4.53e-06 |
# |    explained_variance | -30.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 57599     |
# |    policy_loss        | 5.11e-09  |
# |    value_loss         | 0.00139   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.4      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 57700     |
# |    time_elapsed       | 597       |
# |    total_timesteps    | 288500    |
# | train/                |           |
# |    entropy_loss       | -5.58e-06 |
# |    explained_variance | -2.32     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 57699     |
# |    policy_loss        | 2.95e-11  |
# |    value_loss         | 1.1e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.4     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 57800    |
# |    time_elapsed       | 597      |
# |    total_timesteps    | 289000   |
# | train/                |          |
# |    entropy_loss       | -0.131   |
# |    explained_variance | -1.08    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57799    |
# |    policy_loss        | 0.091    |
# |    value_loss         | 1.5      |
# ------------------------------------
# Num timesteps: 289170
# Best mean reward: 61.66 - Last mean reward per episode: 58.75
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.6     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 57900    |
# |    time_elapsed       | 598      |
# |    total_timesteps    | 289500   |
# | train/                |          |
# |    entropy_loss       | -0.00024 |
# |    explained_variance | -2.55    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57899    |
# |    policy_loss        | 1.62e-07 |
# |    value_loss         | 0.000886 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.6     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 58000    |
# |    time_elapsed       | 599      |
# |    total_timesteps    | 290000   |
# | train/                |          |
# |    entropy_loss       | -0.0399  |
# |    explained_variance | -0.0608  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57999    |
# |    policy_loss        | -0.009   |
# |    value_loss         | 1.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.6     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 58100    |
# |    time_elapsed       | 600      |
# |    total_timesteps    | 290500   |
# | train/                |          |
# |    entropy_loss       | -0.00223 |
# |    explained_variance | -11.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58099    |
# |    policy_loss        | 4e-07    |
# |    value_loss         | 0.000291 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.6     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 58200    |
# |    time_elapsed       | 601      |
# |    total_timesteps    | 291000   |
# | train/                |          |
# |    entropy_loss       | -0.0368  |
# |    explained_variance | -0.0187  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58199    |
# |    policy_loss        | 0.00405  |
# |    value_loss         | 0.274    |
# ------------------------------------
# Num timesteps: 291312
# Best mean reward: 61.66 - Last mean reward per episode: 60.81
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.7      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 58300     |
# |    time_elapsed       | 602       |
# |    total_timesteps    | 291500    |
# | train/                |           |
# |    entropy_loss       | -9.75e-06 |
# |    explained_variance | 0.599     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58299     |
# |    policy_loss        | 2.51e-09  |
# |    value_loss         | 5.6e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.7     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 58400    |
# |    time_elapsed       | 603      |
# |    total_timesteps    | 292000   |
# | train/                |          |
# |    entropy_loss       | -0.112   |
# |    explained_variance | -1.07    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58399    |
# |    policy_loss        | -0.00282 |
# |    value_loss         | 0.00254  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.7      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 58500     |
# |    time_elapsed       | 604       |
# |    total_timesteps    | 292500    |
# | train/                |           |
# |    entropy_loss       | -0.00736  |
# |    explained_variance | -7.28     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58499     |
# |    policy_loss        | -1.81e-05 |
# |    value_loss         | 0.000799  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.7      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 58600     |
# |    time_elapsed       | 605       |
# |    total_timesteps    | 293000    |
# | train/                |           |
# |    entropy_loss       | -0.000392 |
# |    explained_variance | 0.575     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58599     |
# |    policy_loss        | 2.14e-07  |
# |    value_loss         | 4.65e-05  |
# -------------------------------------
# Num timesteps: 293454
# Best mean reward: 61.66 - Last mean reward per episode: 59.50
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.7     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 58700    |
# |    time_elapsed       | 607      |
# |    total_timesteps    | 293500   |
# | train/                |          |
# |    entropy_loss       | -0.201   |
# |    explained_variance | 0.00169  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58699    |
# |    policy_loss        | 0.0599   |
# |    value_loss         | 0.394    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.8     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 58800    |
# |    time_elapsed       | 607      |
# |    total_timesteps    | 294000   |
# | train/                |          |
# |    entropy_loss       | -0.143   |
# |    explained_variance | -43.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58799    |
# |    policy_loss        | 0.00123  |
# |    value_loss         | 0.00285  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.8     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 58900    |
# |    time_elapsed       | 608      |
# |    total_timesteps    | 294500   |
# | train/                |          |
# |    entropy_loss       | -0.00695 |
# |    explained_variance | -9.41    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58899    |
# |    policy_loss        | 6.38e-05 |
# |    value_loss         | 0.00655  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.8      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 59000     |
# |    time_elapsed       | 609       |
# |    total_timesteps    | 295000    |
# | train/                |           |
# |    entropy_loss       | -1.42e-05 |
# |    explained_variance | -3.3      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58999     |
# |    policy_loss        | 4.16e-09  |
# |    value_loss         | 2.97e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.8      |
# | time/                 |           |
# |    fps                | 483       |
# |    iterations         | 59100     |
# |    time_elapsed       | 610       |
# |    total_timesteps    | 295500    |
# | train/                |           |
# |    entropy_loss       | -0.0148   |
# |    explained_variance | -7.63     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59099     |
# |    policy_loss        | -5.79e-06 |
# |    value_loss         | 0.000102  |
# -------------------------------------
# Num timesteps: 295596
# Best mean reward: 61.66 - Last mean reward per episode: 60.37
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.8     |
# | time/                 |          |
# |    fps                | 483      |
# |    iterations         | 59200    |
# |    time_elapsed       | 611      |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -0.0832  |
# |    explained_variance | -50.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59199    |
# |    policy_loss        | -0.00905 |
# |    value_loss         | 0.0444   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.8     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 59300    |
# |    time_elapsed       | 612      |
# |    total_timesteps    | 296500   |
# | train/                |          |
# |    entropy_loss       | -0.00135 |
# |    explained_variance | -28      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59299    |
# |    policy_loss        | 1.68e-06 |
# |    value_loss         | 0.0018   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.8      |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 59400     |
# |    time_elapsed       | 613       |
# |    total_timesteps    | 297000    |
# | train/                |           |
# |    entropy_loss       | -5.92e-05 |
# |    explained_variance | -92.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59399     |
# |    policy_loss        | -4.07e-08 |
# |    value_loss         | 0.000129  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.8     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 59500    |
# |    time_elapsed       | 614      |
# |    total_timesteps    | 297500   |
# | train/                |          |
# |    entropy_loss       | -0.0818  |
# |    explained_variance | -15      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59499    |
# |    policy_loss        | 0.000208 |
# |    value_loss         | 0.000314 |
# ------------------------------------
# Num timesteps: 297738
# Best mean reward: 61.66 - Last mean reward per episode: 60.44
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55       |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 59600    |
# |    time_elapsed       | 615      |
# |    total_timesteps    | 298000   |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | -1.53    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59599    |
# |    policy_loss        | 0.000861 |
# |    value_loss         | 0.00246  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55        |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 59700     |
# |    time_elapsed       | 616       |
# |    total_timesteps    | 298500    |
# | train/                |           |
# |    entropy_loss       | -0.00342  |
# |    explained_variance | -5.43     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59699     |
# |    policy_loss        | -5.95e-05 |
# |    value_loss         | 0.0217    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55       |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 59800    |
# |    time_elapsed       | 616      |
# |    total_timesteps    | 299000   |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | 0.00912  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59799    |
# |    policy_loss        | 0.179    |
# |    value_loss         | 9.26     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55       |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 59900    |
# |    time_elapsed       | 618      |
# |    total_timesteps    | 299500   |
# | train/                |          |
# |    entropy_loss       | -0.0803  |
# |    explained_variance | -0.0521  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59899    |
# |    policy_loss        | -0.0563  |
# |    value_loss         | 0.918    |
# ------------------------------------
# Num timesteps: 299880
# Best mean reward: 61.66 - Last mean reward per episode: 61.58
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55        |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60000     |
# |    time_elapsed       | 619       |
# |    total_timesteps    | 300000    |
# | train/                |           |
# |    entropy_loss       | -4.37e-06 |
# |    explained_variance | 0.214     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59999     |
# |    policy_loss        | -1.61e-10 |
# |    value_loss         | 9.96e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55        |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60100     |
# |    time_elapsed       | 620       |
# |    total_timesteps    | 300500    |
# | train/                |           |
# |    entropy_loss       | -0.00427  |
# |    explained_variance | -3.46     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60099     |
# |    policy_loss        | -1.98e-05 |
# |    value_loss         | 0.00111   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55        |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60200     |
# |    time_elapsed       | 621       |
# |    total_timesteps    | 301000    |
# | train/                |           |
# |    entropy_loss       | -0.00746  |
# |    explained_variance | -30.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60199     |
# |    policy_loss        | -2.22e-05 |
# |    value_loss         | 0.00181   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55        |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60300     |
# |    time_elapsed       | 622       |
# |    total_timesteps    | 301500    |
# | train/                |           |
# |    entropy_loss       | -0.0303   |
# |    explained_variance | -451      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60299     |
# |    policy_loss        | -4.05e-05 |
# |    value_loss         | 7.99e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55        |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60400     |
# |    time_elapsed       | 623       |
# |    total_timesteps    | 302000    |
# | train/                |           |
# |    entropy_loss       | -0.09     |
# |    explained_variance | -1.74     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60399     |
# |    policy_loss        | -0.000742 |
# |    value_loss         | 0.00068   |
# -------------------------------------
# Num timesteps: 302022
# Best mean reward: 61.66 - Last mean reward per episode: 61.85
# Saving new best model to /tmp/gym/best_model.zip
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.3      |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60500     |
# |    time_elapsed       | 624       |
# |    total_timesteps    | 302500    |
# | train/                |           |
# |    entropy_loss       | -0.00691  |
# |    explained_variance | -1.56e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60499     |
# |    policy_loss        | -6.14e-05 |
# |    value_loss         | 0.0229    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.3      |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60600     |
# |    time_elapsed       | 625       |
# |    total_timesteps    | 303000    |
# | train/                |           |
# |    entropy_loss       | -0.000618 |
# |    explained_variance | -20.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60599     |
# |    policy_loss        | -2.19e-06 |
# |    value_loss         | 0.00267   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.3      |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 60700     |
# |    time_elapsed       | 626       |
# |    total_timesteps    | 303500    |
# | train/                |           |
# |    entropy_loss       | -6.37e-06 |
# |    explained_variance | -10.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 60699     |
# |    policy_loss        | -2.06e-09 |
# |    value_loss         | 0.000133  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.3     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 60800    |
# |    time_elapsed       | 626      |
# |    total_timesteps    | 304000   |
# | train/                |          |
# |    entropy_loss       | -0.0428  |
# |    explained_variance | 0.0592   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60799    |
# |    policy_loss        | -0.0255  |
# |    value_loss         | 10.6     |
# ------------------------------------
# Num timesteps: 304164
# Best mean reward: 61.85 - Last mean reward per episode: 64.74
# Saving new best model to /tmp/gym/best_model.zip
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.5     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 60900    |
# |    time_elapsed       | 627      |
# |    total_timesteps    | 304500   |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | -8.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60899    |
# |    policy_loss        | 0.00721  |
# |    value_loss         | 0.00269  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.5     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 61000    |
# |    time_elapsed       | 628      |
# |    total_timesteps    | 305000   |
# | train/                |          |
# |    entropy_loss       | -0.124   |
# |    explained_variance | -0.00786 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 60999    |
# |    policy_loss        | -0.0937  |
# |    value_loss         | 5.64     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.5      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 61100     |
# |    time_elapsed       | 629       |
# |    total_timesteps    | 305500    |
# | train/                |           |
# |    entropy_loss       | -5.32e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61099     |
# |    policy_loss        | -3.74e-09 |
# |    value_loss         | 0.000175  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.5      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 61200     |
# |    time_elapsed       | 630       |
# |    total_timesteps    | 306000    |
# | train/                |           |
# |    entropy_loss       | -5.12e-06 |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61199     |
# |    policy_loss        | -1.4e-09  |
# |    value_loss         | 6.47e-05  |
# -------------------------------------
# Num timesteps: 306306
# Best mean reward: 64.74 - Last mean reward per episode: 64.24
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.5      |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 61300     |
# |    time_elapsed       | 632       |
# |    total_timesteps    | 306500    |
# | train/                |           |
# |    entropy_loss       | -0.0576   |
# |    explained_variance | -2.46     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61299     |
# |    policy_loss        | -0.000307 |
# |    value_loss         | 0.000265  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.5      |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 61400     |
# |    time_elapsed       | 633       |
# |    total_timesteps    | 307000    |
# | train/                |           |
# |    entropy_loss       | -0.000207 |
# |    explained_variance | -2.05     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61399     |
# |    policy_loss        | 6.4e-05   |
# |    value_loss         | 12.1      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.5     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 61500    |
# |    time_elapsed       | 634      |
# |    total_timesteps    | 307500   |
# | train/                |          |
# |    entropy_loss       | -0.00726 |
# |    explained_variance | -771     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61499    |
# |    policy_loss        | 4.16e-06 |
# |    value_loss         | 9.44e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.5      |
# | time/                 |           |
# |    fps                | 484       |
# |    iterations         | 61600     |
# |    time_elapsed       | 635       |
# |    total_timesteps    | 308000    |
# | train/                |           |
# |    entropy_loss       | -0.151    |
# |    explained_variance | -0.0334   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61599     |
# |    policy_loss        | -0.000729 |
# |    value_loss         | 0.266     |
# -------------------------------------
# Num timesteps: 308448
# Best mean reward: 64.74 - Last mean reward per episode: 62.67
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.9     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 61700    |
# |    time_elapsed       | 636      |
# |    total_timesteps    | 308500   |
# | train/                |          |
# |    entropy_loss       | -0.241   |
# |    explained_variance | 0.0106   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61699    |
# |    policy_loss        | 0.0707   |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.9     |
# | time/                 |          |
# |    fps                | 484      |
# |    iterations         | 61800    |
# |    time_elapsed       | 637      |
# |    total_timesteps    | 309000   |
# | train/                |          |
# |    entropy_loss       | -0.0305  |
# |    explained_variance | 0.404    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61799    |
# |    policy_loss        | 0.000841 |
# |    value_loss         | 0.00764  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.9     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 61900    |
# |    time_elapsed       | 638      |
# |    total_timesteps    | 309500   |
# | train/                |          |
# |    entropy_loss       | -0.545   |
# |    explained_variance | -6.86    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 61899    |
# |    policy_loss        | -0.0013  |
# |    value_loss         | 0.000227 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.9      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 62000     |
# |    time_elapsed       | 638       |
# |    total_timesteps    | 310000    |
# | train/                |           |
# |    entropy_loss       | -0.00118  |
# |    explained_variance | -4.84     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 61999     |
# |    policy_loss        | -1.66e-06 |
# |    value_loss         | 0.000107  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.9     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 62100    |
# |    time_elapsed       | 639      |
# |    total_timesteps    | 310500   |
# | train/                |          |
# |    entropy_loss       | -0.00694 |
# |    explained_variance | 0.00714  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62099    |
# |    policy_loss        | 0.000471 |
# |    value_loss         | 2.46     |
# ------------------------------------
# Num timesteps: 310590
# Best mean reward: 64.74 - Last mean reward per episode: 63.12
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56        |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 62200     |
# |    time_elapsed       | 640       |
# |    total_timesteps    | 311000    |
# | train/                |           |
# |    entropy_loss       | -0.000303 |
# |    explained_variance | -55.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62199     |
# |    policy_loss        | 1.44e-06  |
# |    value_loss         | 0.00216   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56       |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 62300    |
# |    time_elapsed       | 641      |
# |    total_timesteps    | 311500   |
# | train/                |          |
# |    entropy_loss       | -0.375   |
# |    explained_variance | 0.0855   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62299    |
# |    policy_loss        | -0.00177 |
# |    value_loss         | 0.000218 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56       |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 62400    |
# |    time_elapsed       | 642      |
# |    total_timesteps    | 312000   |
# | train/                |          |
# |    entropy_loss       | -0.0624  |
# |    explained_variance | -0.495   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62399    |
# |    policy_loss        | 0.00489  |
# |    value_loss         | 0.0842   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56       |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 62500    |
# |    time_elapsed       | 643      |
# |    total_timesteps    | 312500   |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | -26      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62499    |
# |    policy_loss        | 0.000146 |
# |    value_loss         | 0.00104  |
# ------------------------------------
# Num timesteps: 312732
# Best mean reward: 64.74 - Last mean reward per episode: 63.67
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.1     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 62600    |
# |    time_elapsed       | 644      |
# |    total_timesteps    | 313000   |
# | train/                |          |
# |    entropy_loss       | -7.4e-07 |
# |    explained_variance | -5.89    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 62599    |
# |    policy_loss        | -0       |
# |    value_loss         | 0.000615 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.1      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 62700     |
# |    time_elapsed       | 646       |
# |    total_timesteps    | 313500    |
# | train/                |           |
# |    entropy_loss       | -2.01e-05 |
# |    explained_variance | -4.32     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62699     |
# |    policy_loss        | 1.01e-08  |
# |    value_loss         | 0.000494  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.1      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 62800     |
# |    time_elapsed       | 647       |
# |    total_timesteps    | 314000    |
# | train/                |           |
# |    entropy_loss       | -0.00882  |
# |    explained_variance | -9.44     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62799     |
# |    policy_loss        | -2.55e-05 |
# |    value_loss         | 0.000366  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.1      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 62900     |
# |    time_elapsed       | 648       |
# |    total_timesteps    | 314500    |
# | train/                |           |
# |    entropy_loss       | -0.0253   |
# |    explained_variance | -10.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62899     |
# |    policy_loss        | -6.62e-05 |
# |    value_loss         | 0.000432  |
# -------------------------------------
# Num timesteps: 314874
# Best mean reward: 64.74 - Last mean reward per episode: 62.80
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.4      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 63000     |
# |    time_elapsed       | 649       |
# |    total_timesteps    | 315000    |
# | train/                |           |
# |    entropy_loss       | -1.13e-05 |
# |    explained_variance | -1.98     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 62999     |
# |    policy_loss        | -3.33e-09 |
# |    value_loss         | 0.000248  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.4      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 63100     |
# |    time_elapsed       | 650       |
# |    total_timesteps    | 315500    |
# | train/                |           |
# |    entropy_loss       | -2.61e-05 |
# |    explained_variance | -2.34     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 63099     |
# |    policy_loss        | -2.11e-07 |
# |    value_loss         | 0.00524   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.4      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 63200     |
# |    time_elapsed       | 651       |
# |    total_timesteps    | 316000    |
# | train/                |           |
# |    entropy_loss       | -0.00154  |
# |    explained_variance | 0.0421    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 63199     |
# |    policy_loss        | -1.08e-05 |
# |    value_loss         | 0.0189    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.4     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 63300    |
# |    time_elapsed       | 651      |
# |    total_timesteps    | 316500   |
# | train/                |          |
# |    entropy_loss       | -0.142   |
# |    explained_variance | -3.48    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63299    |
# |    policy_loss        | 0.0389   |
# |    value_loss         | 0.0805   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.7     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 63400    |
# |    time_elapsed       | 652      |
# |    total_timesteps    | 317000   |
# | train/                |          |
# |    entropy_loss       | -0.2     |
# |    explained_variance | -41.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63399    |
# |    policy_loss        | -0.0212  |
# |    value_loss         | 0.00963  |
# ------------------------------------
# Num timesteps: 317016
# Best mean reward: 64.74 - Last mean reward per episode: 63.26
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.7     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 63500    |
# |    time_elapsed       | 653      |
# |    total_timesteps    | 317500   |
# | train/                |          |
# |    entropy_loss       | -0.022   |
# |    explained_variance | 0.157    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63499    |
# |    policy_loss        | -1.2e-05 |
# |    value_loss         | 8.84e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.7      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 63600     |
# |    time_elapsed       | 654       |
# |    total_timesteps    | 318000    |
# | train/                |           |
# |    entropy_loss       | -0.000127 |
# |    explained_variance | -4.59     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 63599     |
# |    policy_loss        | 7.15e-08  |
# |    value_loss         | 0.00014   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.7     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 63700    |
# |    time_elapsed       | 655      |
# |    total_timesteps    | 318500   |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | -62.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63699    |
# |    policy_loss        | 7.32e-05 |
# |    value_loss         | 4.72e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.7     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 63800    |
# |    time_elapsed       | 656      |
# |    total_timesteps    | 319000   |
# | train/                |          |
# |    entropy_loss       | -0.0329  |
# |    explained_variance | -1.96    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63799    |
# |    policy_loss        | 0.00742  |
# |    value_loss         | 1.71     |
# ------------------------------------
# Num timesteps: 319158
# Best mean reward: 64.74 - Last mean reward per episode: 61.30
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.8     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 63900    |
# |    time_elapsed       | 657      |
# |    total_timesteps    | 319500   |
# | train/                |          |
# |    entropy_loss       | -0.0271  |
# |    explained_variance | -41.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63899    |
# |    policy_loss        | 0.000112 |
# |    value_loss         | 0.00285  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.8     |
# | time/                 |          |
# |    fps                | 485      |
# |    iterations         | 64000    |
# |    time_elapsed       | 659      |
# |    total_timesteps    | 320000   |
# | train/                |          |
# |    entropy_loss       | -0.173   |
# |    explained_variance | -13      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 63999    |
# |    policy_loss        | -0.00103 |
# |    value_loss         | 0.000931 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.8      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 64100     |
# |    time_elapsed       | 660       |
# |    total_timesteps    | 320500    |
# | train/                |           |
# |    entropy_loss       | -0.00063  |
# |    explained_variance | -96.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64099     |
# |    policy_loss        | -5.71e-08 |
# |    value_loss         | 7.52e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.8      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 64200     |
# |    time_elapsed       | 661       |
# |    total_timesteps    | 321000    |
# | train/                |           |
# |    entropy_loss       | -0.0121   |
# |    explained_variance | -113      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64199     |
# |    policy_loss        | -8.77e-05 |
# |    value_loss         | 0.00045   |
# -------------------------------------
# Num timesteps: 321300
# Best mean reward: 64.74 - Last mean reward per episode: 60.99
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 56.9      |
# | time/                 |           |
# |    fps                | 485       |
# |    iterations         | 64300     |
# |    time_elapsed       | 662       |
# |    total_timesteps    | 321500    |
# | train/                |           |
# |    entropy_loss       | -2.11e-06 |
# |    explained_variance | -9.68     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64299     |
# |    policy_loss        | -3.98e-09 |
# |    value_loss         | 0.000724  |
# -------------------------------------
# ------------------------------------
# ...
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 83300     |
# |    time_elapsed       | 851       |
# |    total_timesteps    | 416500    |
# | train/                |           |
# |    entropy_loss       | -0.0388   |
# |    explained_variance | -7.46     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83299     |
# |    policy_loss        | -0.000106 |
# |    value_loss         | 0.000473  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54       |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 83400    |
# |    time_elapsed       | 852      |
# |    total_timesteps    | 417000   |
# | train/                |          |
# |    entropy_loss       | -0.0379  |
# |    explained_variance | -99.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 83399    |
# |    policy_loss        | -0.00885 |
# |    value_loss         | 0.00419  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54        |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 83500     |
# |    time_elapsed       | 853       |
# |    total_timesteps    | 417500    |
# | train/                |           |
# |    entropy_loss       | -1.29e-06 |
# |    explained_variance | -3.65     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83499     |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000432  |
# -------------------------------------
# Num timesteps: 417690
# Best mean reward: 64.74 - Last mean reward per episode: 65.79
# Saving new best model to /tmp/gym/best_model.zip
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54       |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 83600    |
# |    time_elapsed       | 854      |
# |    total_timesteps    | 418000   |
# | train/                |          |
# |    entropy_loss       | -0.0023  |
# |    explained_variance | 0.408    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 83599    |
# |    policy_loss        | -2.7e-06 |
# |    value_loss         | 0.000139 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54        |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 83700     |
# |    time_elapsed       | 855       |
# |    total_timesteps    | 418500    |
# | train/                |           |
# |    entropy_loss       | -7.74e-05 |
# |    explained_variance | -64.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83699     |
# |    policy_loss        | -1.87e-08 |
# |    value_loss         | 3.99e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54       |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 83800    |
# |    time_elapsed       | 856      |
# |    total_timesteps    | 419000   |
# | train/                |          |
# |    entropy_loss       | -0.131   |
# |    explained_variance | 0.0156   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 83799    |
# |    policy_loss        | 0.0147   |
# |    value_loss         | 0.808    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.4      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 83900     |
# |    time_elapsed       | 857       |
# |    total_timesteps    | 419500    |
# | train/                |           |
# |    entropy_loss       | -0.00853  |
# |    explained_variance | -11.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 83899     |
# |    policy_loss        | -8.19e-05 |
# |    value_loss         | 0.00433   |
# -------------------------------------
# Num timesteps: 419832
# Best mean reward: 65.79 - Last mean reward per episode: 66.62
# Saving new best model to /tmp/gym/best_model.zip
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.4     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 84000    |
# |    time_elapsed       | 858      |
# |    total_timesteps    | 420000   |
# | train/                |          |
# |    entropy_loss       | -0.00434 |
# |    explained_variance | -35.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 83999    |
# |    policy_loss        | 0.00028  |
# |    value_loss         | 0.142    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 54.4     |
# | time/                 |          |
# |    fps                | 488      |
# |    iterations         | 84100    |
# |    time_elapsed       | 859      |
# |    total_timesteps    | 420500   |
# | train/                |          |
# |    entropy_loss       | -0.0057  |
# |    explained_variance | -0.00981 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84099    |
# |    policy_loss        | 0.00065  |
# |    value_loss         | 1.45     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 54.4      |
# | time/                 |           |
# |    fps                | 488       |
# |    iterations         | 84200     |
# |    time_elapsed       | 860       |
# |    total_timesteps    | 421000    |
# | train/                |           |
# |    entropy_loss       | -0.00011  |
# |    explained_variance | -68.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84199     |
# |    policy_loss        | -8.19e-07 |
# |    value_loss         | 0.00473   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.2      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 84300     |
# |    time_elapsed       | 861       |
# |    total_timesteps    | 421500    |
# | train/                |           |
# |    entropy_loss       | -0.0127   |
# |    explained_variance | -268      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84299     |
# |    policy_loss        | -0.000115 |
# |    value_loss         | 0.00188   |
# -------------------------------------
# Num timesteps: 421974
# Best mean reward: 66.62 - Last mean reward per episode: 69.74
# Saving new best model to /tmp/gym/best_model.zip
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.2      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 84400     |
# |    time_elapsed       | 862       |
# |    total_timesteps    | 422000    |
# | train/                |           |
# |    entropy_loss       | -6.15e-07 |
# |    explained_variance | -18.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84399     |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00201   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.2      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 84500     |
# |    time_elapsed       | 863       |
# |    total_timesteps    | 422500    |
# | train/                |           |
# |    entropy_loss       | -7.52e-07 |
# |    explained_variance | -14.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84499     |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000308  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.2     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 84600    |
# |    time_elapsed       | 864      |
# |    total_timesteps    | 423000   |
# | train/                |          |
# |    entropy_loss       | -0.0762  |
# |    explained_variance | -41.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84599    |
# |    policy_loss        | 0.00512  |
# |    value_loss         | 0.0638   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.8      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 84700     |
# |    time_elapsed       | 865       |
# |    total_timesteps    | 423500    |
# | train/                |           |
# |    entropy_loss       | -2.72e-05 |
# |    explained_variance | -8.48     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84699     |
# |    policy_loss        | 9.78e-08  |
# |    value_loss         | 0.0031    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.8     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 84800    |
# |    time_elapsed       | 866      |
# |    total_timesteps    | 424000   |
# | train/                |          |
# |    entropy_loss       | -0.133   |
# |    explained_variance | -38.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84799    |
# |    policy_loss        | -0.00402 |
# |    value_loss         | 0.0194   |
# ------------------------------------
# Num timesteps: 424116
# Best mean reward: 69.74 - Last mean reward per episode: 69.81
# Saving new best model to /tmp/gym/best_model.zip
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.8      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 84900     |
# |    time_elapsed       | 867       |
# |    total_timesteps    | 424500    |
# | train/                |           |
# |    entropy_loss       | -0.00015  |
# |    explained_variance | -20.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 84899     |
# |    policy_loss        | -3.57e-07 |
# |    value_loss         | 0.000209  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.8     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 85000    |
# |    time_elapsed       | 868      |
# |    total_timesteps    | 425000   |
# | train/                |          |
# |    entropy_loss       | -0.00247 |
# |    explained_variance | -7.66    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 84999    |
# |    policy_loss        | 6.69e-06 |
# |    value_loss         | 0.000176 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.9     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 85100    |
# |    time_elapsed       | 869      |
# |    total_timesteps    | 425500   |
# | train/                |          |
# |    entropy_loss       | -7.5e-08 |
# |    explained_variance | -3.35    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 85099    |
# |    policy_loss        | -0       |
# |    value_loss         | 0.000424 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.9      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 85200     |
# |    time_elapsed       | 870       |
# |    total_timesteps    | 426000    |
# | train/                |           |
# |    entropy_loss       | -0.00791  |
# |    explained_variance | 0.0156    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 85199     |
# |    policy_loss        | -6.41e-05 |
# |    value_loss         | 0.00842   |
# -------------------------------------
# Num timesteps: 426258
# Best mean reward: 69.81 - Last mean reward per episode: 71.11
# Saving new best model to /tmp/gym/best_model.zip
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.9      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 85300     |
# |    time_elapsed       | 871       |
# |    total_timesteps    | 426500    |
# | train/                |           |
# |    entropy_loss       | -4.1e-05  |
# |    explained_variance | -10.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 85299     |
# |    policy_loss        | -2.28e-08 |
# |    value_loss         | 0.000321  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 55.9      |
# | time/                 |           |
# |    fps                | 489       |
# |    iterations         | 85400     |
# |    time_elapsed       | 872       |
# |    total_timesteps    | 427000    |
# | train/                |           |
# |    entropy_loss       | -3.18e-05 |
# |    explained_variance | -9.97e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 85399     |
# |    policy_loss        | -4.47e-08 |
# |    value_loss         | 0.000321  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 55.9     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 85500    |
# |    time_elapsed       | 874      |
# |    total_timesteps    | 427500   |
# | train/                |          |
# |    entropy_loss       | -0.242   |
# |    explained_variance | 0.0608   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 85499    |
# |    policy_loss        | 0.186    |
# |    value_loss         | 2.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 56.1     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 85600    |
# |    time_elapsed       | 875      |
# |    total_timesteps    | 428000   |
# | train/                |          |
# |    entropy_loss       | -0.0026  |
# |    explained_variance | -15.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 85599    |
# |    policy_loss        | 1.89e-05 |
# |    value_loss         | 0.00219  |
# ------------------------------------
# Num timesteps: 428400
# Best mean reward: 71.11 - Last mean reward per episode: 71.49
# Saving new best model to /tmp/gym/best_model.zip

# %%
plot_results(log_dir)

# %% [markdown]
# Evaluate the model for 5 repetitions

# %%
total_profit_list = []
total_reward_list = []
total_sharpe_ratio_list = []

for i in range(5):

  env = MyCustomEnv(df=test_df, frame_bound=(WINDOW_SIZE, len(test_df)), window_size=WINDOW_SIZE)

  observation, info = env.reset(seed=2024)
  while True:
      action = model.predict(observation)
      observation, reward, terminated, truncated, info = env.step(action[0])
      done = terminated or truncated

      if done:
          print("info:", info)
          total_profit_list.append(info['total_profit'])
          total_reward_list.append(info['total_reward'])
          break

  plt.cla()
  env.unwrapped.render_all()
  plt.show()

  AWR = env.history['total_profit']

  average_sharpe_ratio = np.mean(AWR) / np.std(AWR)
  print('Sharpe Ratio:', average_sharpe_ratio)
  total_sharpe_ratio_list.append(average_sharpe_ratio)
# Out:
# info: {'total_reward': 477.1217710000001, 'total_profit': 1048.3938484215853, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 4.3125105352947095
# info: {'total_reward': 557.6998860000001, 'total_profit': 1751.339447826065, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 2.7586939460758755
# info: {'total_reward': 302.59981800000014, 'total_profit': 827.766028488324, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 5.122542317115519
# info: {'total_reward': 541.4918490000005, 'total_profit': 1296.3102512793416, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 3.519837997463812
# info: {'total_reward': 474.2478190000003, 'total_profit': 1056.5036715592387, 'position': <Positions.Short: 0>}
# Sharpe Ratio: 4.270562343539254

# %%
print('average sharpe ratio: ',np.mean(total_sharpe_ratio_list))
print('average profit: ',np.mean(total_profit_list))
# Out:
# average sharpe ratio:  3.9968294278978336
# average profit:  1196.0626495149108
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
