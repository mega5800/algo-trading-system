# %% [markdown]
# ### 1. Installing dependencies

# %%
# !pip install gymnasium gym-anytrading pandas matplotlib stable-baselines3[extra] finta
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: gym-anytrading in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: finta in /usr/local/lib/python3.10/dist-packages (1.3)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.3.1+cu121)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.15.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.7.1)
# Requirement already satisfied: shimmy~=1.3.0 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: autorom~=0.6.1 in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (71.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3[extra]) (12.5.82)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %% [markdown]
# ### 2. importing packages

# %%
import gymnasium as gym
import gym_anytrading
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


from gym_anytrading.envs import TradingEnv, ForexEnv, StocksEnv, Actions, Positions

from stable_baselines3 import DQN
from stable_baselines3 import A2C
from stable_baselines3 import PPO



from gym_anytrading.envs import StocksEnv
from finta import TA

# %% [markdown]
# ### Constant

# %%
WINDOW_SIZE = 14
DATASET_PATH = '/content/TSLA.csv'

# %% [markdown]
# ### 3. Read the dataset and preprocess it

# %%
df = pd.read_csv(DATASET_PATH)

# %%
df['Date'] = pd.to_datetime(df.Date)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df.set_index('Date', inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2956 entries, 2010-06-29 to 2022-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2956 non-null   float64
#  1   High       2956 non-null   float64
#  2   Low        2956 non-null   float64
#  3   Close      2956 non-null   float64
#  4   Adj Close  2956 non-null   float64
#  5   Volume     2956 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 161.7 KB

# %%
df['SMA'] = TA.SMA(df, WINDOW_SIZE)
df['RSI'] = TA.RSI(df, WINDOW_SIZE)
df['MOM'] = TA.MOM(df, WINDOW_SIZE)
df['OBV'] = TA.OBV(df,'close')
df['EMA'] = TA.EMA(df, WINDOW_SIZE)
df['Stochastic oscillator'] = TA.AO(df,WINDOW_SIZE)
df['AD'] = TA.ADL(df)
df['ROC'] = TA.ROC(df,WINDOW_SIZE)
df.fillna(0, inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(50)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              Open   High    Low  Close  Adj Close    Volume       SMA  \
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500  0.000000
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500  0.000000
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000  0.000000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000  0.000000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500  0.000000
# 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500  0.000000
# 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000  0.000000
# 2010-07-09  3.516  3.580  3.310  3.480      3.480  20253000  0.000000
# 2010-07-12  3.590  3.614  3.400  3.410      3.410  11012500  0.000000
# 2010-07-13  3.478  3.728  3.380  3.628      3.628  13400500  0.000000
# 2010-07-14  3.588  4.030  3.552  3.968      3.968  20976000  0.000000
# 2010-07-15  3.988  4.300  3.800  3.978      3.978  18699000  0.000000
# 2010-07-16  4.140  4.260  4.010  4.128      4.128  13106500  0.000000
# 2010-07-19  4.274  4.450  4.184  4.382      4.382  12432500  3.901714
# 2010-07-20  4.370  4.370  4.010  4.060      4.060   9126500  3.850429
# 2010-07-21  4.132  4.180  3.900  4.044      4.044   6262500  3.798857
# 2010-07-22  4.100  4.250  4.074  4.200      4.200   4789000  3.785143
# 2010-07-23  4.238  4.312  4.212  4.258      4.258   3268000  3.815000
# 2010-07-26  4.300  4.300  4.060  4.190      4.190   4611000  3.884143
# 2010-07-27  4.182  4.236  4.052  4.110      4.110   3098500  3.952000
# 2010-07-28  4.110  4.180  4.102  4.144      4.144   2336000  3.998571
# 2010-07-29  4.154  4.176  4.000  4.070      4.070   3080000  4.040714
# 2010-07-30  4.040  4.088  3.910  3.988      3.988   2134500  4.082000
# 2010-08-02  4.100  4.194  4.066  4.184      4.184   3590500  4.121714
# 2010-08-03  4.200  4.390  4.164  4.390      4.390   6152500  4.151857
# 2010-08-04  4.390  4.436  4.170  4.252      4.252   4565000  4.171429
# 2010-08-05  4.308  4.310  4.010  4.090      4.090   3981000  4.168714
# 2010-08-06  4.020  4.032  3.904  3.918      3.918   3709500  4.135571
# 2010-08-09  3.980  3.996  3.890  3.920      3.920   4063500  4.125571
# 2010-08-10  3.930  3.930  3.764  3.806      3.806   6406500  4.108571
# 2010-08-11  3.738  3.776  3.570  3.580      3.580   3988000  4.064286
# 2010-08-12  3.560  3.580  3.478  3.520      3.520   3455000  4.011571
# 2010-08-13  3.636  3.690  3.532  3.664      3.664   3170000  3.974000
# 2010-08-16  3.690  3.760  3.652  3.756      3.756   2429000  3.948714
# 2010-08-17  3.792  3.880  3.756  3.830      3.830   2239500  3.926286
# 2010-08-18  3.918  3.918  3.720  3.754      3.754   3006500  3.903714
# 2010-08-19  3.708  3.850  3.666  3.758      3.758   2895500  3.887286
# 2010-08-20  3.730  3.822  3.702  3.820      3.820   1480000  3.861286
# 2010-08-23  3.818  4.078  3.800  4.026      4.026   5440500  3.835286
# 2010-08-24  3.850  3.942  3.790  3.840      3.840   3365500  3.805857
# 2010-08-25  3.832  3.996  3.712  3.980      3.980   2516500  3.798000
# 2010-08-26  3.978  4.054  3.920  3.950      3.950   2169000  3.800286
# 2010-08-27  3.950  3.974  3.900  3.940      3.940   1898000  3.801714
# 2010-08-30  3.940  4.038  3.922  3.974      3.974   3664000  3.813714
# 2010-08-31  3.932  3.958  3.866  3.896      3.896   1005500  3.836286
# 2010-09-01  3.924  4.138  3.920  4.090      4.090   2474500  3.877000
# 2010-09-02  4.074  4.248  4.062  4.212      4.212   2435500  3.916143
# 2010-09-03  4.174  4.260  4.132  4.210      4.210   2173000  3.948571
# 2010-09-07  4.122  4.200  4.100  4.108      4.108   1217000  3.968429
# 2010-09-08  4.132  4.190  4.120  4.180      4.180   1442000  3.998857
#
#                   RSI    MOM          OBV       EMA  Stochastic oscillator  \
# Date
# 2010-06-29   0.000000  0.000          0.0  4.778000               0.000000
# 2010-06-30   0.000000  0.000  -85935500.0  4.771571               0.000000
# 2010-07-01   0.000000  0.000 -127029500.0  4.626574               0.000000
# 2010-07-02   0.000000  0.000 -152728500.0  4.385939               0.000000
# 2010-07-06   0.000000  0.000 -187063000.0  4.082269               0.000000
# 2010-07-07   0.000000  0.000 -221671500.0  3.868872               0.000000
# 2010-07-08  20.112173  0.000 -183114500.0  3.789457               0.000000
# 2010-07-09  19.955945  0.000 -203367500.0  3.728932               0.000000
# 2010-07-12  19.027444  0.000 -214380000.0  3.670209               0.000000
# 2010-07-13  29.957330  0.000 -200979500.0  3.662813               0.000000
# 2010-07-14  42.902359  0.000 -180003500.0  3.714139               0.000000
# 2010-07-15  43.234658  0.000 -161304500.0  3.757021               0.000000
# 2010-07-16  48.112728  0.000 -148198000.0  3.815601               0.000000
# 2010-07-19  55.142300  0.000 -135765500.0  3.902895               0.020971
# 2010-07-20  46.535206 -0.718 -144892000.0  3.926615               0.152743
# 2010-07-21  46.149737 -0.722 -151154500.0  3.944030               0.297686
# 2010-07-22  50.458627 -0.192 -146365500.0  3.981445               0.352729
# 2010-07-23  51.996562  0.418 -143097500.0  4.021355               0.372343
# 2010-07-26  50.035402  0.968 -147708500.0  4.045429               0.302300
# 2010-07-27  47.753439  0.950 -150807000.0  4.054560               0.222886
# 2010-07-28  48.821732  0.652 -148471000.0  4.067107               0.183657
# 2010-07-29  46.588916  0.590 -151551000.0  4.067510               0.122929
# 2010-07-30  44.177840  0.578 -153685500.0  4.056499               0.035186
# 2010-08-02  50.740038  0.556 -150095000.0  4.074066              -0.015957
# 2010-08-03  56.524737  0.422 -143942500.0  4.117401              -0.024071
# 2010-08-04  52.110005  0.274 -148507500.0  4.135793              -0.009743
# 2010-08-05  47.427123 -0.038 -152488500.0  4.129557               0.002871
# 2010-08-06  43.007969 -0.464 -156198000.0  4.100826               0.021600
# 2010-08-09  43.074390 -0.140 -152134500.0  4.076330               0.001843
# 2010-08-10  40.198567 -0.238 -158541000.0  4.039787              -0.070371
# 2010-08-11  35.183563 -0.620 -162529000.0  3.977747              -0.161443
# 2010-08-12  33.971830 -0.738 -165984000.0  3.916081              -0.235286
# 2010-08-13  39.368907 -0.526 -162814000.0  3.882169              -0.266043
# 2010-08-16  42.597196 -0.354 -160385000.0  3.865216              -0.282157
# 2010-08-17  45.127988 -0.314 -158145500.0  3.860489              -0.264886
# 2010-08-18  43.029732 -0.316 -161152000.0  3.846207              -0.216471
# 2010-08-19  43.179475 -0.230 -158256500.0  3.834387              -0.153457
# 2010-08-20  45.567693 -0.364 -156776500.0  3.832460              -0.096971
# 2010-08-23  52.683745 -0.364 -151336000.0  3.858363              -0.026229
# 2010-08-24  46.741926 -0.412 -154701500.0  3.855907               0.014586
# 2010-08-25  51.202965 -0.110 -152185000.0  3.872500               0.043443
# 2010-08-26  50.231988  0.032 -154354000.0  3.882858               0.087886
# 2010-08-27  49.892354  0.020 -156252000.0  3.890494               0.123314
# 2010-08-30  51.102890  0.168 -152588000.0  3.901648               0.122014
# 2010-08-31  48.224550  0.316 -153593500.0  3.900894               0.114143
# 2010-09-01  55.011708  0.570 -151119000.0  3.926143               0.113429
# 2010-09-02  58.680025  0.548 -148683500.0  3.964303               0.108171
# 2010-09-03  58.595674  0.454 -150856500.0  3.997097               0.124971
# 2010-09-07  54.308051  0.278 -152073500.0  4.011897               0.135257
# 2010-09-08  56.715728  0.426 -150631500.0  4.034328               0.159857
#
#                       AD        ROC
# Date
# 2010-06-29  6.590845e+07   0.000000
# 2010-06-30 -7.233279e+06   0.000000
# 2010-07-01 -2.374361e+07   0.000000
# 2010-07-02 -4.370570e+07   0.000000
# 2010-07-06 -7.342934e+07   0.000000
# 2010-07-07 -7.363909e+07   0.000000
# 2010-07-08 -3.745482e+07   0.000000
# 2010-07-09 -3.220405e+07   0.000000
# 2010-07-12 -4.218734e+07   0.000000
# 2010-07-13 -3.648828e+07   0.000000
# 2010-07-14 -2.095375e+07   0.000000
# 2010-07-15 -2.633906e+07   0.000000
# 2010-07-16 -2.707303e+07   0.000000
# 2010-07-19 -2.099699e+07   0.000000
# 2010-07-20 -2.758835e+07 -15.027208
# 2010-07-21 -2.740942e+07 -15.148972
# 2010-07-22 -2.534145e+07  -4.371585
# 2010-07-23 -2.560289e+07  10.885417
# 2010-07-26 -2.521864e+07  30.043451
# 2010-07-27 -2.636374e+07  30.063291
# 2010-07-28 -2.618404e+07  18.671249
# 2010-07-29 -2.681404e+07  16.954023
# 2010-07-30 -2.707786e+07  16.950147
# 2010-08-02 -2.404837e+07  15.325248
# 2010-08-03 -1.789587e+07  10.635081
# 2010-08-04 -1.964636e+07   6.887883
# 2010-08-05 -2.150416e+07  -0.920543
# 2010-08-06 -2.440221e+07 -10.588772
# 2010-08-09 -2.616561e+07  -3.448276
# 2010-08-10 -2.933027e+07  -5.885262
# 2010-08-11 -3.293109e+07 -14.761905
# 2010-08-12 -3.354079e+07 -17.332081
# 2010-08-13 -3.141408e+07 -12.553699
# 2010-08-16 -2.916501e+07  -8.613139
# 2010-08-17 -2.873156e+07  -7.577220
# 2010-08-18 -3.070552e+07  -7.764128
# 2010-08-19 -3.070552e+07  -5.767302
# 2010-08-20 -2.927486e+07  -8.699809
# 2010-08-23 -2.586965e+07  -8.291572
# 2010-08-24 -2.702101e+07  -9.689558
# 2010-08-25 -2.478806e+07  -2.689487
# 2010-08-26 -2.598586e+07   0.816743
# 2010-08-27 -2.583197e+07   0.510204
# 2010-08-30 -2.621100e+07   4.414083
# 2010-08-31 -2.656074e+07   8.826816
# 2010-09-01 -2.517593e+07  16.193182
# 2010-09-02 -2.368321e+07  14.956332
# 2010-09-03 -2.320786e+07  12.087327
# 2010-09-07 -2.423014e+07   7.258486
# 2010-09-08 -2.320014e+07  11.347896

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    diff = np.insert(np.diff(prices), 0, 0)
    signal_features = env.df.loc[:, ['Close','SMA', 'RSI', 'MOM', 'OBV', 'EMA', 'Stochastic oscillator', 'AD', 'ROC']].to_numpy()[start:end]
    # Reshape diff to (282, 1)
    diff_reshaped = diff.reshape(len(diff), 1)

    # Concatenate along the second axis (columns)
    signal_features = np.concatenate((signal_features, diff_reshaped), axis=1)


    return prices, signal_features
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals

# %%
train_df = df.loc[df.index < '2019-01-01']
test_df = df.loc[df.index >= '2019-01-01']

print('train_df: ',len(train_df))
print('test_df: ',len(test_df))
# Out:
# train_df:  2142
# test_df:  814

# %%
train_df.shape
# Out:
# (2142, 14)

# %%
env = MyCustomEnv(df=train_df, frame_bound=(WINDOW_SIZE, len(train_df)), window_size=WINDOW_SIZE)

# %%
env.signal_features[:1,:]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[4.77800000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.77800000e+00, 0.00000000e+00, 6.59084531e+07,
#         0.00000000e+00, 0.00000000e+00]])

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# Discrete: describes a discrete space where {0, 1, …, n-1} are the possible values our observation or action can take. Values can be shifted to {a, a+1, …, a+n-1} using an optional argument.

# %%
env.action_space.sample()
# Out:
# 0

# %% [markdown]
# Sell = 0
#
# Buy = 1

# %%
env.observation_space
# Out:
# Box(-10000000000.0, 10000000000.0, (14, 10), float32)

# %% [markdown]
# Box: describes an n-dimensional continuous space. It’s a bounded space where we can define the upper and lower limits which describe the valid values our observations can take.

# %%
env.observation_space.sample()
# Out:
# array([[ 8.7271332e+09, -2.8864402e+09, -2.4639363e+09,  6.0388250e+09,
#          9.4009876e+09, -7.1809971e+09, -4.5143296e+09,  8.2103718e+08,
#          7.8067389e+09,  1.4515931e+09],
#        [ 5.4349094e+08, -6.5697239e+09,  2.4447173e+09, -3.7437681e+09,
#          6.7138714e+09,  4.1181678e+09, -2.2403843e+09, -2.2543155e+09,
#         -8.4512824e+09,  4.5210816e+07],
#        [-7.2105718e+09, -3.4868808e+09, -5.8069468e+07, -9.7278392e+09,
#          7.6702577e+09, -7.3940060e+09, -7.2632320e+09, -2.9386708e+09,
#         -6.5009935e+09, -1.9536006e+09],
#        [-7.5317443e+09,  7.6382218e+09,  8.6751386e+09,  8.9122376e+09,
#          7.6304886e+09,  7.4088745e+09,  1.7778263e+09,  8.6943949e+09,
#         -7.2002924e+09, -7.1363036e+09],
#        [ 4.6677463e+09,  6.8483154e+09,  1.4572678e+09,  8.9730284e+09,
#          3.6028943e+09,  7.3474688e+09,  8.4463483e+09,  7.3090063e+09,
#          8.2267361e+09,  3.4120020e+09],
#        [-4.6567699e+08, -1.6453385e+09, -1.5795899e+09,  7.5356385e+09,
#         -5.7326008e+09, -7.3450255e+09,  6.5597988e+09, -5.1240556e+09,
#          4.4730660e+09,  5.4279608e+09],
#        [-3.4902566e+09, -6.3736352e+08, -4.0089773e+08, -9.2800502e+09,
#         -8.1282555e+09,  9.3353329e+09, -5.8693038e+09,  7.6400266e+09,
#          3.6493949e+09, -5.2068408e+09],
#        [-2.2219484e+09, -2.2977170e+08,  9.6924211e+09, -7.5891077e+09,
#          6.7802035e+09,  1.9076335e+09, -8.3547233e+09, -4.8953037e+09,
#         -2.5608082e+09,  3.4302136e+09],
#        [ 7.5025300e+09,  9.4154998e+09, -5.9213471e+09, -2.2207939e+09,
#          5.3187338e+08,  9.5953132e+09, -9.4851830e+09, -6.7345925e+09,
#         -8.0506332e+09,  7.6409375e+09],
#        [-3.2352750e+09,  2.7606669e+09, -9.3413386e+09, -2.6758121e+09,
#         -1.1551369e+09, -2.9653711e+09,  2.3102298e+09, -5.5795610e+09,
#         -6.4386621e+09, -2.9489795e+09],
#        [-2.7886669e+09, -3.8943017e+09,  1.1068623e+09, -6.5398989e+09,
#         -9.4536233e+09,  3.6522844e+09, -7.0117192e+09,  4.0295803e+09,
#         -9.9859968e+09, -3.4958474e+08],
#        [ 1.7897080e+09,  5.4153139e+08,  7.8084413e+09, -8.1592806e+09,
#         -7.2396554e+09,  6.8142500e+09, -5.6634131e+08,  3.8658493e+09,
#         -9.8471148e+09, -2.0533064e+09],
#        [ 5.5939758e+09, -7.4437140e+09,  8.3234765e+09, -9.7415496e+09,
#         -3.1799997e+09,  9.1932580e+09, -7.6314665e+09, -1.4824332e+09,
#         -6.2682614e+09,  1.4204375e+09],
#        [ 4.3275090e+09, -6.1534510e+09, -6.1496955e+09, -5.0922153e+09,
#         -7.3040113e+09, -6.9325153e+09,  5.9700731e+09,  4.9004298e+09,
#          5.1936758e+09, -1.6298676e+09]], dtype=float32)

# %% [markdown]
# ### 4. Create the environment and do some random action on it

# %%
observation = env.reset(seed=2024)
while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    # env.render()
    if done:
        print("info:", info)
        break

plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info: {'total_reward': 45.983995000000014, 'total_profit': 0.004284681837425818, 'position': <Positions.Short: 0>}

# %% [markdown]
# ### 5 creating and training the model

# %%
model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000000)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    value_loss         | 0.0372   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.4     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 170700   |
# |    time_elapsed       | 2174     |
# |    total_timesteps    | 853500   |
# | train/                |          |
# |    entropy_loss       | -0.146   |
# |    explained_variance | -1.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 170699   |
# |    policy_loss        | 0.0128   |
# |    value_loss         | 0.0132   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.4      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 170800    |
# |    time_elapsed       | 2175      |
# |    total_timesteps    | 854000    |
# | train/                |           |
# |    entropy_loss       | -0.0623   |
# |    explained_variance | -1.6      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 170799    |
# |    policy_loss        | -0.000687 |
# |    value_loss         | 0.00248   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.4     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 170900   |
# |    time_elapsed       | 2176     |
# |    total_timesteps    | 854500   |
# | train/                |          |
# |    entropy_loss       | -0.00346 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 170899   |
# |    policy_loss        | 0.00066  |
# |    value_loss         | 0.943    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.4      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 171000    |
# |    time_elapsed       | 2177      |
# |    total_timesteps    | 855000    |
# | train/                |           |
# |    entropy_loss       | -0.00493  |
# |    explained_variance | -1.39e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 170999    |
# |    policy_loss        | 5.76e-06  |
# |    value_loss         | 0.000364  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.4      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 171100    |
# |    time_elapsed       | 2178      |
# |    total_timesteps    | 855500    |
# | train/                |           |
# |    entropy_loss       | -7.22e-06 |
# |    explained_variance | -4.73     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 171099    |
# |    policy_loss        | -4.02e-08 |
# |    value_loss         | 0.00381   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.4     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 171200   |
# |    time_elapsed       | 2179     |
# |    total_timesteps    | 856000   |
# | train/                |          |
# |    entropy_loss       | -0.0165  |
# |    explained_variance | -0.00104 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 171199   |
# |    policy_loss        | -0.022   |
# |    value_loss         | 27.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.4     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 171300   |
# |    time_elapsed       | 2181     |
# |    total_timesteps    | 856500   |
# | train/                |          |
# |    entropy_loss       | -0.0421  |
# |    explained_variance | -0.00355 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 171299   |
# |    policy_loss        | 0.0747   |
# |    value_loss         | 19.6     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.4      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 171400    |
# |    time_elapsed       | 2183      |
# |    total_timesteps    | 857000    |
# | train/                |           |
# |    entropy_loss       | -1.37e-10 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 171399    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00147   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 171500    |
# |    time_elapsed       | 2184      |
# |    total_timesteps    | 857500    |
# | train/                |           |
# |    entropy_loss       | -0.0454   |
# |    explained_variance | -4.58     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 171499    |
# |    policy_loss        | -0.000484 |
# |    value_loss         | 0.00485   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.6     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 171600   |
# |    time_elapsed       | 2185     |
# |    total_timesteps    | 858000   |
# | train/                |          |
# |    entropy_loss       | -0.141   |
# |    explained_variance | -85.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 171599   |
# |    policy_loss        | -0.00091 |
# |    value_loss         | 0.00128  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 171700    |
# |    time_elapsed       | 2186      |
# |    total_timesteps    | 858500    |
# | train/                |           |
# |    entropy_loss       | -0.0782   |
# |    explained_variance | -172      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 171699    |
# |    policy_loss        | -0.000142 |
# |    value_loss         | 0.000224  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 171800    |
# |    time_elapsed       | 2187      |
# |    total_timesteps    | 859000    |
# | train/                |           |
# |    entropy_loss       | -7.98e-10 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 171799    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000489  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.5      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 171900    |
# |    time_elapsed       | 2189      |
# |    total_timesteps    | 859500    |
# | train/                |           |
# |    entropy_loss       | -0.00483  |
# |    explained_variance | -19.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 171899    |
# |    policy_loss        | -2.23e-05 |
# |    value_loss         | 0.00285   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.5      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 172000    |
# |    time_elapsed       | 2190      |
# |    total_timesteps    | 860000    |
# | train/                |           |
# |    entropy_loss       | -0.00336  |
# |    explained_variance | 0.744     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 171999    |
# |    policy_loss        | -6.33e-05 |
# |    value_loss         | 0.00831   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.5     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 172100   |
# |    time_elapsed       | 2191     |
# |    total_timesteps    | 860500   |
# | train/                |          |
# |    entropy_loss       | -0.00163 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 172099   |
# |    policy_loss        | -1.9e-06 |
# |    value_loss         | 0.000156 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.5     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 172200   |
# |    time_elapsed       | 2192     |
# |    total_timesteps    | 861000   |
# | train/                |          |
# |    entropy_loss       | -0.00415 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 172199   |
# |    policy_loss        | -2.9e-06 |
# |    value_loss         | 0.000239 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.6     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 172300   |
# |    time_elapsed       | 2194     |
# |    total_timesteps    | 861500   |
# | train/                |          |
# |    entropy_loss       | -0.00383 |
# |    explained_variance | -0.0917  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 172299   |
# |    policy_loss        | -2e-05   |
# |    value_loss         | 0.00903  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.6     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 172400   |
# |    time_elapsed       | 2195     |
# |    total_timesteps    | 862000   |
# | train/                |          |
# |    entropy_loss       | -0.134   |
# |    explained_variance | -0.776   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 172399   |
# |    policy_loss        | -0.0171  |
# |    value_loss         | 0.016    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 172500    |
# |    time_elapsed       | 2197      |
# |    total_timesteps    | 862500    |
# | train/                |           |
# |    entropy_loss       | -0.011    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 172499    |
# |    policy_loss        | -2.95e-05 |
# |    value_loss         | 0.000492  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.6     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 172600   |
# |    time_elapsed       | 2198     |
# |    total_timesteps    | 863000   |
# | train/                |          |
# |    entropy_loss       | -0.0101  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 172599   |
# |    policy_loss        | -0.00369 |
# |    value_loss         | 7.27     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 172700    |
# |    time_elapsed       | 2199      |
# |    total_timesteps    | 863500    |
# | train/                |           |
# |    entropy_loss       | -0.000531 |
# |    explained_variance | -828      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 172699    |
# |    policy_loss        | -1.93e-07 |
# |    value_loss         | 0.00144   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.7     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 172800   |
# |    time_elapsed       | 2200     |
# |    total_timesteps    | 864000   |
# | train/                |          |
# |    entropy_loss       | -0.136   |
# |    explained_variance | -45.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 172799   |
# |    policy_loss        | -0.13    |
# |    value_loss         | 0.0955   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.7      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 172900    |
# |    time_elapsed       | 2201      |
# |    total_timesteps    | 864500    |
# | train/                |           |
# |    entropy_loss       | -0.000717 |
# |    explained_variance | -1.72     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 172899    |
# |    policy_loss        | -3.6e-06  |
# |    value_loss         | 0.00202   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.7      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 173000    |
# |    time_elapsed       | 2203      |
# |    total_timesteps    | 865000    |
# | train/                |           |
# |    entropy_loss       | -0.00107  |
# |    explained_variance | -10.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 172999    |
# |    policy_loss        | -2.33e-06 |
# |    value_loss         | 0.00127   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.7      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 173100    |
# |    time_elapsed       | 2204      |
# |    total_timesteps    | 865500    |
# | train/                |           |
# |    entropy_loss       | -0.137    |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 173099    |
# |    policy_loss        | -0.0655   |
# |    value_loss         | 3.99      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.8     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 173200   |
# |    time_elapsed       | 2205     |
# |    total_timesteps    | 866000   |
# | train/                |          |
# |    entropy_loss       | -0.235   |
# |    explained_variance | -3.29    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 173199   |
# |    policy_loss        | -0.0279  |
# |    value_loss         | 0.0103   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.8      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 173300    |
# |    time_elapsed       | 2206      |
# |    total_timesteps    | 866500    |
# | train/                |           |
# |    entropy_loss       | -0.000786 |
# |    explained_variance | -7.7      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 173299    |
# |    policy_loss        | -3.09e-06 |
# |    value_loss         | 0.000589  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.8     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 173400   |
# |    time_elapsed       | 2207     |
# |    total_timesteps    | 867000   |
# | train/                |          |
# |    entropy_loss       | -0.588   |
# |    explained_variance | -46.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 173399   |
# |    policy_loss        | -0.0258  |
# |    value_loss         | 0.00259  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.8      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 173500    |
# |    time_elapsed       | 2209      |
# |    total_timesteps    | 867500    |
# | train/                |           |
# |    entropy_loss       | -3.02e-10 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 173499    |
# |    policy_loss        | -0        |
# |    value_loss         | 3.6e-07   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.9     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 173600   |
# |    time_elapsed       | 2211     |
# |    total_timesteps    | 868000   |
# | train/                |          |
# |    entropy_loss       | -0.0189  |
# |    explained_variance | 0.0598   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 173599   |
# |    policy_loss        | 0.00104  |
# |    value_loss         | 0.283    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 49.9     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 173700   |
# |    time_elapsed       | 2212     |
# |    total_timesteps    | 868500   |
# | train/                |          |
# |    entropy_loss       | -0.0638  |
# |    explained_variance | -1.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 173699   |
# |    policy_loss        | 0.00645  |
# |    value_loss         | 0.0806   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.9      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 173800    |
# |    time_elapsed       | 2213      |
# |    total_timesteps    | 869000    |
# | train/                |           |
# |    entropy_loss       | -3.19e-05 |
# |    explained_variance | 0.0233    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 173799    |
# |    policy_loss        | -1.7e-08  |
# |    value_loss         | 6.21e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 49.9      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 173900    |
# |    time_elapsed       | 2214      |
# |    total_timesteps    | 869500    |
# | train/                |           |
# |    entropy_loss       | -0.000139 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 173899    |
# |    policy_loss        | -1.19e-07 |
# |    value_loss         | 0.000144  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 174000   |
# |    time_elapsed       | 2215     |
# |    total_timesteps    | 870000   |
# | train/                |          |
# |    entropy_loss       | -0.00373 |
# |    explained_variance | -61.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 173999   |
# |    policy_loss        | 4.22e-06 |
# |    value_loss         | 0.00789  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 174100    |
# |    time_elapsed       | 2216      |
# |    total_timesteps    | 870500    |
# | train/                |           |
# |    entropy_loss       | -0.000964 |
# |    explained_variance | -15.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174099    |
# |    policy_loss        | -1.99e-06 |
# |    value_loss         | 0.00644   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 174200    |
# |    time_elapsed       | 2218      |
# |    total_timesteps    | 871000    |
# | train/                |           |
# |    entropy_loss       | -0.00105  |
# |    explained_variance | -11.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174199    |
# |    policy_loss        | -3.55e-06 |
# |    value_loss         | 0.00233   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 174300    |
# |    time_elapsed       | 2219      |
# |    total_timesteps    | 871500    |
# | train/                |           |
# |    entropy_loss       | -4.67e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174299    |
# |    policy_loss        | -4.26e-08 |
# |    value_loss         | 0.000199  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 174400    |
# |    time_elapsed       | 2220      |
# |    total_timesteps    | 872000    |
# | train/                |           |
# |    entropy_loss       | -1.48e-06 |
# |    explained_variance | -1.1      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174399    |
# |    policy_loss        | -3.06e-10 |
# |    value_loss         | 0.000157  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.4     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 174500   |
# |    time_elapsed       | 2221     |
# |    total_timesteps    | 872500   |
# | train/                |          |
# |    entropy_loss       | -0.012   |
# |    explained_variance | 0.854    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 174499   |
# |    policy_loss        | 2.75e-05 |
# |    value_loss         | 0.000241 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.4      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 174600    |
# |    time_elapsed       | 2223      |
# |    total_timesteps    | 873000    |
# | train/                |           |
# |    entropy_loss       | -1.52e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174599    |
# |    policy_loss        | -2.19e-08 |
# |    value_loss         | 0.000642  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.4      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 174700    |
# |    time_elapsed       | 2224      |
# |    total_timesteps    | 873500    |
# | train/                |           |
# |    entropy_loss       | -0.0606   |
# |    explained_variance | -4.32e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174699    |
# |    policy_loss        | -6.92e-05 |
# |    value_loss         | 0.00238   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.4      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 174800    |
# |    time_elapsed       | 2226      |
# |    total_timesteps    | 874000    |
# | train/                |           |
# |    entropy_loss       | -1.09e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174799    |
# |    policy_loss        | -6.12e-09 |
# |    value_loss         | 0.000176  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.5     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 174900   |
# |    time_elapsed       | 2227     |
# |    total_timesteps    | 874500   |
# | train/                |          |
# |    entropy_loss       | -0.0379  |
# |    explained_variance | -0.0295  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 174899   |
# |    policy_loss        | 0.00306  |
# |    value_loss         | 0.0834   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.5      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 175000    |
# |    time_elapsed       | 2228      |
# |    total_timesteps    | 875000    |
# | train/                |           |
# |    entropy_loss       | -0.0152   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 174999    |
# |    policy_loss        | -2.99e-05 |
# |    value_loss         | 0.00068   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.5      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 175100    |
# |    time_elapsed       | 2229      |
# |    total_timesteps    | 875500    |
# | train/                |           |
# |    entropy_loss       | -0.00238  |
# |    explained_variance | -9.17     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 175099    |
# |    policy_loss        | -6.74e-06 |
# |    value_loss         | 0.00068   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.5      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 175200    |
# |    time_elapsed       | 2230      |
# |    total_timesteps    | 876000    |
# | train/                |           |
# |    entropy_loss       | -0.00013  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 175199    |
# |    policy_loss        | -2.34e-07 |
# |    value_loss         | 0.000176  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 175300    |
# |    time_elapsed       | 2231      |
# |    total_timesteps    | 876500    |
# | train/                |           |
# |    entropy_loss       | -1.32e-06 |
# |    explained_variance | -14.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 175299    |
# |    policy_loss        | -8.28e-10 |
# |    value_loss         | 0.00107   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.6     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 175400   |
# |    time_elapsed       | 2232     |
# |    total_timesteps    | 877000   |
# | train/                |          |
# |    entropy_loss       | -0.0189  |
# |    explained_variance | -40.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 175399   |
# |    policy_loss        | 0.00043  |
# |    value_loss         | 0.123    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 175500    |
# |    time_elapsed       | 2233      |
# |    total_timesteps    | 877500    |
# | train/                |           |
# |    entropy_loss       | -5.27e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 175499    |
# |    policy_loss        | -3.88e-08 |
# |    value_loss         | 0.000126  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.6      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 175600    |
# |    time_elapsed       | 2235      |
# |    total_timesteps    | 878000    |
# | train/                |           |
# |    entropy_loss       | -0.00255  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 175599    |
# |    policy_loss        | -0.000172 |
# |    value_loss         | 0.243     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.8     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 175700   |
# |    time_elapsed       | 2236     |
# |    total_timesteps    | 878500   |
# | train/                |          |
# |    entropy_loss       | -0.287   |
# |    explained_variance | -0.0308  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 175699   |
# |    policy_loss        | -0.0926  |
# |    value_loss         | 0.0238   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.8     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 175800   |
# |    time_elapsed       | 2238     |
# |    total_timesteps    | 879000   |
# | train/                |          |
# |    entropy_loss       | -0.262   |
# |    explained_variance | -13.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 175799   |
# |    policy_loss        | -0.0114  |
# |    value_loss         | 0.00494  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.8     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 175900   |
# |    time_elapsed       | 2240     |
# |    total_timesteps    | 879500   |
# | train/                |          |
# |    entropy_loss       | -0.0933  |
# |    explained_variance | 0.00874  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 175899   |
# |    policy_loss        | 0.0251   |
# |    value_loss         | 5.1      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.8      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 176000    |
# |    time_elapsed       | 2241      |
# |    total_timesteps    | 880000    |
# | train/                |           |
# |    entropy_loss       | -4.79e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 175999    |
# |    policy_loss        | -4.06e-08 |
# |    value_loss         | 0.00018   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.8      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 176100    |
# |    time_elapsed       | 2242      |
# |    total_timesteps    | 880500    |
# | train/                |           |
# |    entropy_loss       | -0.000162 |
# |    explained_variance | 0.604     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 176099    |
# |    policy_loss        | -9.71e-08 |
# |    value_loss         | 3.92e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.8     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 176200   |
# |    time_elapsed       | 2243     |
# |    total_timesteps    | 881000   |
# | train/                |          |
# |    entropy_loss       | -0.184   |
# |    explained_variance | 0.0864   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 176199   |
# |    policy_loss        | 0.112    |
# |    value_loss         | 0.107    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 50.8     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 176300   |
# |    time_elapsed       | 2244     |
# |    total_timesteps    | 881500   |
# | train/                |          |
# |    entropy_loss       | -0.00011 |
# |    explained_variance | -3.1     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 176299   |
# |    policy_loss        | 8.91e-07 |
# |    value_loss         | 0.00344  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.8      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 176400    |
# |    time_elapsed       | 2245      |
# |    total_timesteps    | 882000    |
# | train/                |           |
# |    entropy_loss       | -0.0796   |
# |    explained_variance | -96.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 176399    |
# |    policy_loss        | -0.000843 |
# |    value_loss         | 0.00185   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 50.8      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 176500    |
# |    time_elapsed       | 2246      |
# |    total_timesteps    | 882500    |
# | train/                |           |
# |    entropy_loss       | -0.00493  |
# |    explained_variance | -12.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 176499    |
# |    policy_loss        | -3.98e-05 |
# |    value_loss         | 0.00161   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 176600   |
# |    time_elapsed       | 2247     |
# |    total_timesteps    | 883000   |
# | train/                |          |
# |    entropy_loss       | -0.158   |
# |    explained_variance | -5.38    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 176599   |
# |    policy_loss        | 0.000104 |
# |    value_loss         | 0.00563  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 176700   |
# |    time_elapsed       | 2248     |
# |    total_timesteps    | 883500   |
# | train/                |          |
# |    entropy_loss       | -0.138   |
# |    explained_variance | -23.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 176699   |
# |    policy_loss        | -0.0113  |
# |    value_loss         | 0.0021   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 176800   |
# |    time_elapsed       | 2250     |
# |    total_timesteps    | 884000   |
# | train/                |          |
# |    entropy_loss       | -0.0629  |
# |    explained_variance | -16      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 176799   |
# |    policy_loss        | 7.59e-05 |
# |    value_loss         | 0.000122 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 51.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 176900    |
# |    time_elapsed       | 2252      |
# |    total_timesteps    | 884500    |
# | train/                |           |
# |    entropy_loss       | -0.00205  |
# |    explained_variance | -90.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 176899    |
# |    policy_loss        | -2.08e-06 |
# |    value_loss         | 0.000695  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 51.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 177000    |
# |    time_elapsed       | 2253      |
# |    total_timesteps    | 885000    |
# | train/                |           |
# |    entropy_loss       | -0.078    |
# |    explained_variance | -81.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 176999    |
# |    policy_loss        | -2.95e-05 |
# |    value_loss         | 0.00475   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 177100   |
# |    time_elapsed       | 2254     |
# |    total_timesteps    | 885500   |
# | train/                |          |
# |    entropy_loss       | -0.119   |
# |    explained_variance | -11.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 177099   |
# |    policy_loss        | 0.00591  |
# |    value_loss         | 0.00502  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 177200   |
# |    time_elapsed       | 2256     |
# |    total_timesteps    | 886000   |
# | train/                |          |
# |    entropy_loss       | -0.0439  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 177199   |
# |    policy_loss        | -0.0274  |
# |    value_loss         | 4.32     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 51.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 177300    |
# |    time_elapsed       | 2257      |
# |    total_timesteps    | 886500    |
# | train/                |           |
# |    entropy_loss       | -0.000689 |
# |    explained_variance | 0.0419    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 177299    |
# |    policy_loss        | 6.07e-06  |
# |    value_loss         | 0.197     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.3     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 177400   |
# |    time_elapsed       | 2258     |
# |    total_timesteps    | 887000   |
# | train/                |          |
# |    entropy_loss       | -0.501   |
# |    explained_variance | -0.136   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 177399   |
# |    policy_loss        | 0.0469   |
# |    value_loss         | 0.00238  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 51.3      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 177500    |
# |    time_elapsed       | 2259      |
# |    total_timesteps    | 887500    |
# | train/                |           |
# |    entropy_loss       | -0.0124   |
# |    explained_variance | -20.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 177499    |
# |    policy_loss        | -2.22e-05 |
# |    value_loss         | 0.00427   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 51.3      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 177600    |
# |    time_elapsed       | 2260      |
# |    total_timesteps    | 888000    |
# | train/                |           |
# |    entropy_loss       | -0.00315  |
# |    explained_variance | -2.39     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 177599    |
# |    policy_loss        | -5.82e-07 |
# |    value_loss         | 0.000219  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.3     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 177700   |
# |    time_elapsed       | 2261     |
# |    total_timesteps    | 888500   |
# | train/                |          |
# |    entropy_loss       | -0.00509 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 177699   |
# |    policy_loss        | 0.000266 |
# |    value_loss         | 0.185    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.3     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 177800   |
# |    time_elapsed       | 2262     |
# |    total_timesteps    | 889000   |
# | train/                |          |
# |    entropy_loss       | -0.129   |
# |    explained_variance | -3.41    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 177799   |
# |    policy_loss        | -0.00107 |
# |    value_loss         | 0.000603 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.5     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 177900   |
# |    time_elapsed       | 2264     |
# |    total_timesteps    | 889500   |
# | train/                |          |
# |    entropy_loss       | -0.214   |
# |    explained_variance | -1.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 177899   |
# |    policy_loss        | -0.00339 |
# |    value_loss         | 0.0201   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 51.5     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 178000   |
# |    time_elapsed       | 2266     |
# |    total_timesteps    | 890000   |
# | train/                |          |
# |    entropy_loss       | -5.7e-07 |
# |    explained_variance | -6.91    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 177999   |
# |    policy_loss        | -0       |
# |    value_loss         | 0.002    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 51.5      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 178100    |
# |    time_elapsed       | 2267      |
# |    total_timesteps    | 890500    |
# | train/                |           |
# |    entropy_loss       | -0.000128 |
# |    explained_variance | -15.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 178099    |
# |    policy_loss        | 1.72e-07  |
# |    value_loss         | 0.000763  |
# -------------------------------------
# ...
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.2      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 197600    |
# |    time_elapsed       | 2519      |
# |    total_timesteps    | 988000    |
# | train/                |           |
# |    entropy_loss       | -0.00438  |
# |    explained_variance | -3.49     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197599    |
# |    policy_loss        | -1.42e-05 |
# |    value_loss         | 0.000705  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 197700   |
# |    time_elapsed       | 2521     |
# |    total_timesteps    | 988500   |
# | train/                |          |
# |    entropy_loss       | -0.0926  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197699   |
# |    policy_loss        | 0.54     |
# |    value_loss         | 1.4      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.2      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 197800    |
# |    time_elapsed       | 2522      |
# |    total_timesteps    | 989000    |
# | train/                |           |
# |    entropy_loss       | -1.23e-05 |
# |    explained_variance | -49.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197799    |
# |    policy_loss        | 6.8e-09   |
# |    value_loss         | 0.000234  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 197900    |
# |    time_elapsed       | 2523      |
# |    total_timesteps    | 989500    |
# | train/                |           |
# |    entropy_loss       | -4.02e-06 |
# |    explained_variance | -39.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 197899    |
# |    policy_loss        | 8.21e-09  |
# |    value_loss         | 0.00572   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 198000   |
# |    time_elapsed       | 2524     |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | -0.0486  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197999   |
# |    policy_loss        | -0.0931  |
# |    value_loss         | 36.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 198100   |
# |    time_elapsed       | 2525     |
# |    total_timesteps    | 990500   |
# | train/                |          |
# |    entropy_loss       | -0.00413 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198099   |
# |    policy_loss        | 1.97e-05 |
# |    value_loss         | 0.00124  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 198200    |
# |    time_elapsed       | 2526      |
# |    total_timesteps    | 991000    |
# | train/                |           |
# |    entropy_loss       | -2.06e-10 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198199    |
# |    policy_loss        | -0        |
# |    value_loss         | 4.13e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53       |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 198300   |
# |    time_elapsed       | 2528     |
# |    total_timesteps    | 991500   |
# | train/                |          |
# |    entropy_loss       | -0.099   |
# |    explained_variance | -0.0845  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198299   |
# |    policy_loss        | 0.00765  |
# |    value_loss         | 0.0821   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53       |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 198400   |
# |    time_elapsed       | 2529     |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -0.219   |
# |    explained_variance | -9.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198399   |
# |    policy_loss        | -0.00987 |
# |    value_loss         | 0.00493  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53        |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 198500    |
# |    time_elapsed       | 2530      |
# |    total_timesteps    | 992500    |
# | train/                |           |
# |    entropy_loss       | -0.00125  |
# |    explained_variance | -0.0695   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198499    |
# |    policy_loss        | -3.65e-05 |
# |    value_loss         | 0.168     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53        |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 198600    |
# |    time_elapsed       | 2531      |
# |    total_timesteps    | 993000    |
# | train/                |           |
# |    entropy_loss       | -0.00325  |
# |    explained_variance | -15.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198599    |
# |    policy_loss        | -6.09e-06 |
# |    value_loss         | 0.000604  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 198700    |
# |    time_elapsed       | 2533      |
# |    total_timesteps    | 993500    |
# | train/                |           |
# |    entropy_loss       | -0.000286 |
# |    explained_variance | 0.122     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198699    |
# |    policy_loss        | 7.49e-07  |
# |    value_loss         | 0.0666    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 198800   |
# |    time_elapsed       | 2535     |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | -0.049   |
# |    explained_variance | -2.7     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198799   |
# |    policy_loss        | 0.00102  |
# |    value_loss         | 0.0024   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 198900    |
# |    time_elapsed       | 2536      |
# |    total_timesteps    | 994500    |
# | train/                |           |
# |    entropy_loss       | -0.00229  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198899    |
# |    policy_loss        | -2.47e-06 |
# |    value_loss         | 0.000123  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 199000    |
# |    time_elapsed       | 2537      |
# |    total_timesteps    | 995000    |
# | train/                |           |
# |    entropy_loss       | -8.51e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 198999    |
# |    policy_loss        | 3.83e-06  |
# |    value_loss         | 1.68      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 199100   |
# |    time_elapsed       | 2538     |
# |    total_timesteps    | 995500   |
# | train/                |          |
# |    entropy_loss       | -0.00414 |
# |    explained_variance | -77.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199099   |
# |    policy_loss        | 0.000121 |
# |    value_loss         | 0.039    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.2     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 199200   |
# |    time_elapsed       | 2539     |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | -0.13    |
# |    explained_variance | -21.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199199   |
# |    policy_loss        | -0.00374 |
# |    value_loss         | 0.0065   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.2      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 199300    |
# |    time_elapsed       | 2541      |
# |    total_timesteps    | 996500    |
# | train/                |           |
# |    entropy_loss       | -0.0209   |
# |    explained_variance | -6.13     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199299    |
# |    policy_loss        | -9.76e-05 |
# |    value_loss         | 0.00175   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.2      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 199400    |
# |    time_elapsed       | 2542      |
# |    total_timesteps    | 997000    |
# | train/                |           |
# |    entropy_loss       | -0.000511 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199399    |
# |    policy_loss        | -5.12e-07 |
# |    value_loss         | 0.000146  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.2      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 199500    |
# |    time_elapsed       | 2543      |
# |    total_timesteps    | 997500    |
# | train/                |           |
# |    entropy_loss       | -2.99e-07 |
# |    explained_variance | -184      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199499    |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000584  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 199600   |
# |    time_elapsed       | 2544     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | -0.915   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199599   |
# |    policy_loss        | 0.00125  |
# |    value_loss         | 0.0236   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 199700    |
# |    time_elapsed       | 2545      |
# |    total_timesteps    | 998500    |
# | train/                |           |
# |    entropy_loss       | -0.0226   |
# |    explained_variance | -0.327    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199699    |
# |    policy_loss        | -4.57e-05 |
# |    value_loss         | 0.000263  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.13e+03  |
# |    ep_rew_mean        | 53.1      |
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 199800    |
# |    time_elapsed       | 2547      |
# |    total_timesteps    | 999000    |
# | train/                |           |
# |    entropy_loss       | -0.0086   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199799    |
# |    policy_loss        | -5.96e-05 |
# |    value_loss         | 0.00257   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 199900   |
# |    time_elapsed       | 2549     |
# |    total_timesteps    | 999500   |
# | train/                |          |
# |    entropy_loss       | -0.108   |
# |    explained_variance | -0.00778 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199899   |
# |    policy_loss        | -3.64    |
# |    value_loss         | 12.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.13e+03 |
# |    ep_rew_mean        | 53.1     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 200000   |
# |    time_elapsed       | 2550     |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -0.113   |
# |    explained_variance | -1       |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199999   |
# |    policy_loss        | -0.00968 |
# |    value_loss         | 0.0706   |
# ------------------------------------

# %% [markdown]
# ### Save model

# %%
# model.save('ppo_1000000_15_senti')

# %%
# del model

# %% [markdown]
# ### Load model

# %%
# model = A2C.load('/content/ppo_1000000_15_senti.zip')

# %% [markdown]
# ### 6. Evaluate the model

# %%
env = MyCustomEnv(df=test_df, frame_bound=(WINDOW_SIZE, len(test_df)), window_size=WINDOW_SIZE)

observation, info = env.reset(seed=2024)
while True:
    # print('ob',observation)
    action = model.predict(observation)
    # print('action',action[0])
    observation, reward, terminated, truncated, info = env.step(action[0])
    done = terminated or truncated

    # env.render()
    if done:
        print("info:", info)
        break

plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info: {'total_reward': 159.832008, 'total_profit': 5.388517194195837, 'position': <Positions.Long: 1>}

# %%
AWR = env.history['total_profit']

average_sharpe_ratio = np.mean(AWR) / np.std(AWR)
print('Sharpe Ratio:', average_sharpe_ratio)
# Out:
# Sharpe Ratio: 2.8148779412102107
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
